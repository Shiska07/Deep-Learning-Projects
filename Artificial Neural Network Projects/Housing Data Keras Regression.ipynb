# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Data/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
#df.isnull().sum()

# %%
plt.figure(figsize = (10,6))
sns.histplot(df['price'],bins = 30, kde = False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(df['bedrooms'])
# Out:
# C:\Users\shisk\anaconda3\envs\py37version\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'price', y = 'sqft_living', data = df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize = (10,6))
sns.boxplot(x = 'bedrooms', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'price', y = 'long', data = df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'price', y = 'lat', data = df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(x = 'long', y = 'lat', data = df, hue = 'price', palette = 'coolwarm' )
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#dropping outliers

# %%
cutoff_price = 3800000
df_bottom99 = df[df['price'] < cutoff_price]

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(x = 'long', y = 'lat', data = df_bottom99, hue = 'price', alpha = 0.2, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x = 'waterfront', y = 'price', data = df, palette = 'magma')
plt.title('Price Distribution Waterfront vs not Waterfront')
# Out:
# Text(0.5, 1.0, 'Price Distribution Waterfront vs not Waterfront')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id', axis = 1)
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].apply(lambda date: date.year) 
df['month'] = df['date'].apply(lambda x: x.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
plt.figure(figsize = (14,6))
sns.boxplot(x = 'month', y = 'price', data = df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
#as the above plot does not show a significant variation

df.groupby('month').mean()['price']. plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df.groupby('year').mean()['price']. plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = df.drop('date', axis = 1)

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
#too many categories so it will be dropped
df = df.drop('zipcode', axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
def renov(year):
    if year > 0:
        return 1
    else:
        return 0

df['renovated'] = df['yr_renovated'].apply(renov)

# %%
df = df.drop('yr_renovated', axis = 1)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built      lat  \
# 0     0          3      7        1180              0      1955  47.5112
# 1     0          3      7        2170            400      1951  47.7210
# 2     0          3      6         770              0      1933  47.7379
# 3     0          5      7        1050            910      1965  47.5208
# 4     0          3      8        1680              0      1987  47.6168
#
#       long  sqft_living15  sqft_lot15  year  month  renovated
# ...

# %%
df['sqft_basement'].value_counts()

#we can leave this as it is as 0 corresponds to no basement
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df = df[df['price'] < cutoff_price]          #dataframe without outliers:This means our model is only good a predicting values lower than cutoff_price
X = df.drop('price', axis = 1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 100)

# %%
'''
Note: We scale our data only after the test train split because while scaling we have to fit our data and we don't want
to use our test data to fit the model since this will mean the model has prior info on the test data
'''
# Out:
# "\nNote: We scale our data only after the test train split because while scaling we have to fit our data and we don't want\nto use our test data to fit the model since this will mean the model has prior info on the test data\n"

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train.shape
# Out:
# (14459, 19)

# %%
#Since we have 19 features, it would make sense to have atlease 19 neurons on each layer

# %%
#MODEL CREATION
# Note: we don't really know how many layers to add or no. of epochs to use, this is a hyperparameter for now

model = Sequential()

model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))

model.add(Dense(1))           #output layer for price

model.compile(optimizer = 'adam', loss = 'mse')

# %%
#MODEL TRAINING

# Note: A validation step will also be added this time. Validation data is only used for testing purposes, it does not 
# affect the weights and biases of the model. WE will also break down our data into batches 

model.fit(x = X_train, y = y_train, validation_data = (X_test, y_test), batch_size = 128, epochs = 400, verbose = 0)

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
# Note: if you see the val_loss start to increase after a point, you might be overfitting
loss_df.plot(figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)
# Out:
# 27198103658.73097

# %%
mean_absolute_error(y_test,predictions)

#this is about 20% of mean price
# Out:
# 103571.94728673839

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.774711126491273

# %%
plt.figure(figsize = (10,6))
plt.scatter(y_test, predictions)
plt.plot(y_test,y_test, 'r')

# %%
#predicting for new data

new_house = df.drop('price', axis = 1).iloc[0]

# %%
new_house
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# year             2014.0000
# month              10.0000
# renovated           0.0000
# Name: 0, dtype: float64

# %%
new_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         4.75112e+01, -1.22257e+02,  1.34000e+03,  5.65000e+03,
#         2.01400e+03,  1.00000e+01,  0.00000e+00])

# %%
new_house.shape
# Out:
# (19,)

# %%
#we need to reshape this
new_house.values.reshape(-1,19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          4.75112e+01, -1.22257e+02,  1.34000e+03,  5.65000e+03,
#          2.01400e+03,  1.00000e+01,  0.00000e+00]])

# %%
new_house = scaler.transform(new_house.values.reshape(-1,19))

# %%
new_house.shape
# Out:
# (1, 19)

# %%
model.predict(new_house)
# Out:
# array([[286009.84]], dtype=float32)

# %%
df.head(1)['price']
# Out:
# 0    221900.0
# Name: price, dtype: float64
