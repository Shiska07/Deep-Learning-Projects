# %%
import torch
torch.manual_seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# get data mean and std for each channel
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# initialize data transformer
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
    ])

# load and transform data
train = datasets.CIFAR10(root='~/.pytorch/CIFAR10',train=True, download=True,transform=transform)
test = datasets.CIFAR10(root='~/.pytorch/CIFAR10',train=False, transform=transform)

train_loader = DataLoader(train, batch_size=64, shuffle=True)
test_loader = DataLoader(test, batch_size=64, shuffle=False)
# Out:
# Files already downloaded and verified

# %%
for images, labels in train_loader:
  print(images.size(), labels.size())
  break
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64])

# %%
# get pre-trained VGG16 model
model = models.vgg16(pretrained=True)
model
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 246MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
# freeze mosel params
for param in model.parameters():
  param.requires_grad = False

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
# unfreeze the classifier layers
for i in range(7):
  model.classifier[0].requires_grad = True

# %%
# define new sequential network
new_seq = nn.Sequential(
                      nn.Linear(4096,512),
                      nn.ReLU(),
                      nn.Dropout(0.5),
                      nn.Linear(512,10),
                      nn.LogSoftmax(dim=1)
                      )

# %%
# replace the final layer of the classifier with this new sequential model
model.classifier[6] = new_seq

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=10, bias=True)
#     (4): LogSoftmax(dim=1)
#   )
# )

# %%
for param in model.parameters():
  print(param.requires_grad)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# True
# True
# True

# %%
# define criterion for loss and optimizer

from torch.optim import Adam

model = model.to(device)

# only trainable parameters should be passed to optimizer in this case
optimizer = Adam(filter(lambda p:p.requires_grad, model.parameters()))
criterion = nn.NLLLoss()

# %% [markdown]
# ### Retrain the Model

# %%
epochs = 1
batch_loss = 0
cum_epoch_loss = 0

for i in range(epochs):
  cum_epoch_loss = 0

  for batch_n, (X_train, y_train) in enumerate(train_loader,1):
    X_train = X_train.to(device)
    y_train = y_train.to(device)

    optimizer.zero_grad()
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()

    batch_loss += loss.item()
    print(f'Epoch({i}/{epochs}) : Batch no ({batch_n}/{len(train_loader)}) : Batch loss : {loss.item()}')

  print(f'Training loss : {batch_loss/len(train_loader)}')
# Out:
# Epoch(0/1) : Batch no (1/782) : Batch loss : 2.2825655937194824
# Epoch(0/1) : Batch no (2/782) : Batch loss : 2.1926777362823486
# Epoch(0/1) : Batch no (3/782) : Batch loss : 2.044671058654785
# Epoch(0/1) : Batch no (4/782) : Batch loss : 1.8856464624404907
# Epoch(0/1) : Batch no (5/782) : Batch loss : 1.7129738330841064
# Epoch(0/1) : Batch no (6/782) : Batch loss : 1.5244320631027222
# Epoch(0/1) : Batch no (7/782) : Batch loss : 1.2131257057189941
# Epoch(0/1) : Batch no (8/782) : Batch loss : 1.3469524383544922
# Epoch(0/1) : Batch no (9/782) : Batch loss : 1.2806134223937988
# Epoch(0/1) : Batch no (10/782) : Batch loss : 0.928964376449585
# Epoch(0/1) : Batch no (11/782) : Batch loss : 1.1841177940368652
# Epoch(0/1) : Batch no (12/782) : Batch loss : 1.15919029712677
# Epoch(0/1) : Batch no (13/782) : Batch loss : 0.9362459182739258
# Epoch(0/1) : Batch no (14/782) : Batch loss : 1.1043065786361694
# Epoch(0/1) : Batch no (15/782) : Batch loss : 0.9515876770019531
# Epoch(0/1) : Batch no (16/782) : Batch loss : 0.9634648561477661
# Epoch(0/1) : Batch no (17/782) : Batch loss : 0.9849407076835632
# Epoch(0/1) : Batch no (18/782) : Batch loss : 0.9526082277297974
# Epoch(0/1) : Batch no (19/782) : Batch loss : 1.1039479970932007
# Epoch(0/1) : Batch no (20/782) : Batch loss : 1.371187448501587
# Epoch(0/1) : Batch no (21/782) : Batch loss : 0.9175522327423096
# Epoch(0/1) : Batch no (22/782) : Batch loss : 0.980137825012207
# Epoch(0/1) : Batch no (23/782) : Batch loss : 0.7717146277427673
# Epoch(0/1) : Batch no (24/782) : Batch loss : 0.7564087510108948
# Epoch(0/1) : Batch no (25/782) : Batch loss : 0.92103511095047
# Epoch(0/1) : Batch no (26/782) : Batch loss : 1.1561554670333862
# Epoch(0/1) : Batch no (27/782) : Batch loss : 0.9203095436096191
# Epoch(0/1) : Batch no (28/782) : Batch loss : 0.7739291191101074
# Epoch(0/1) : Batch no (29/782) : Batch loss : 1.0705015659332275
# Epoch(0/1) : Batch no (30/782) : Batch loss : 0.8986654281616211
# Epoch(0/1) : Batch no (31/782) : Batch loss : 1.157454252243042
# Epoch(0/1) : Batch no (32/782) : Batch loss : 0.9002950191497803
# Epoch(0/1) : Batch no (33/782) : Batch loss : 0.9168927669525146
# Epoch(0/1) : Batch no (34/782) : Batch loss : 0.9803222417831421
# Epoch(0/1) : Batch no (35/782) : Batch loss : 0.9725455045700073
# Epoch(0/1) : Batch no (36/782) : Batch loss : 1.0744694471359253
# Epoch(0/1) : Batch no (37/782) : Batch loss : 1.0485763549804688
# Epoch(0/1) : Batch no (38/782) : Batch loss : 0.8292378187179565
# Epoch(0/1) : Batch no (39/782) : Batch loss : 0.6925430297851562
# Epoch(0/1) : Batch no (40/782) : Batch loss : 0.905950129032135
# Epoch(0/1) : Batch no (41/782) : Batch loss : 0.8618960380554199
# Epoch(0/1) : Batch no (42/782) : Batch loss : 0.7634029984474182
# Epoch(0/1) : Batch no (43/782) : Batch loss : 1.0236788988113403
# Epoch(0/1) : Batch no (44/782) : Batch loss : 1.0710809230804443
# Epoch(0/1) : Batch no (45/782) : Batch loss : 0.8205639123916626
# Epoch(0/1) : Batch no (46/782) : Batch loss : 0.712398111820221
# Epoch(0/1) : Batch no (47/782) : Batch loss : 0.6915526390075684
# Epoch(0/1) : Batch no (48/782) : Batch loss : 0.5836408138275146
# Epoch(0/1) : Batch no (49/782) : Batch loss : 0.933700680732727
# Epoch(0/1) : Batch no (50/782) : Batch loss : 0.7587615251541138
# Epoch(0/1) : Batch no (51/782) : Batch loss : 0.871768057346344
# Epoch(0/1) : Batch no (52/782) : Batch loss : 0.984110951423645
# Epoch(0/1) : Batch no (53/782) : Batch loss : 0.9432564973831177
# Epoch(0/1) : Batch no (54/782) : Batch loss : 0.620306134223938
# Epoch(0/1) : Batch no (55/782) : Batch loss : 0.9327133893966675
# Epoch(0/1) : Batch no (56/782) : Batch loss : 0.6903161406517029
# Epoch(0/1) : Batch no (57/782) : Batch loss : 0.6101028919219971
# Epoch(0/1) : Batch no (58/782) : Batch loss : 1.0682716369628906
# Epoch(0/1) : Batch no (59/782) : Batch loss : 0.7984182834625244
# Epoch(0/1) : Batch no (60/782) : Batch loss : 0.8740119338035583
# Epoch(0/1) : Batch no (61/782) : Batch loss : 0.9026598930358887
# Epoch(0/1) : Batch no (62/782) : Batch loss : 0.5477717518806458
# Epoch(0/1) : Batch no (63/782) : Batch loss : 0.709293782711029
# Epoch(0/1) : Batch no (64/782) : Batch loss : 0.9734665155410767
# Epoch(0/1) : Batch no (65/782) : Batch loss : 0.8091141581535339
# Epoch(0/1) : Batch no (66/782) : Batch loss : 0.7324081659317017
# Epoch(0/1) : Batch no (67/782) : Batch loss : 0.7920544147491455
# Epoch(0/1) : Batch no (68/782) : Batch loss : 1.161512851715088
# Epoch(0/1) : Batch no (69/782) : Batch loss : 0.8693702220916748
# Epoch(0/1) : Batch no (70/782) : Batch loss : 0.8939660787582397
# Epoch(0/1) : Batch no (71/782) : Batch loss : 0.6849746108055115
# Epoch(0/1) : Batch no (72/782) : Batch loss : 0.720192551612854
# Epoch(0/1) : Batch no (73/782) : Batch loss : 0.6440690159797668
# Epoch(0/1) : Batch no (74/782) : Batch loss : 0.8045317530632019
# Epoch(0/1) : Batch no (75/782) : Batch loss : 0.8506692051887512
# Epoch(0/1) : Batch no (76/782) : Batch loss : 0.890709638595581
# Epoch(0/1) : Batch no (77/782) : Batch loss : 0.792069137096405
# Epoch(0/1) : Batch no (78/782) : Batch loss : 0.6893709897994995
# Epoch(0/1) : Batch no (79/782) : Batch loss : 0.6925803422927856
# Epoch(0/1) : Batch no (80/782) : Batch loss : 0.7096530795097351
# Epoch(0/1) : Batch no (81/782) : Batch loss : 0.7847228050231934
# Epoch(0/1) : Batch no (82/782) : Batch loss : 0.6473724246025085
# Epoch(0/1) : Batch no (83/782) : Batch loss : 0.7368265986442566
# Epoch(0/1) : Batch no (84/782) : Batch loss : 0.681818962097168
# Epoch(0/1) : Batch no (85/782) : Batch loss : 0.7272971272468567
# Epoch(0/1) : Batch no (86/782) : Batch loss : 0.8399457335472107
# Epoch(0/1) : Batch no (87/782) : Batch loss : 0.6325165629386902
# Epoch(0/1) : Batch no (88/782) : Batch loss : 0.8168755173683167
# Epoch(0/1) : Batch no (89/782) : Batch loss : 0.8916822075843811
# Epoch(0/1) : Batch no (90/782) : Batch loss : 0.7648937702178955
# Epoch(0/1) : Batch no (91/782) : Batch loss : 0.8293737769126892
# Epoch(0/1) : Batch no (92/782) : Batch loss : 0.7843753695487976
# Epoch(0/1) : Batch no (93/782) : Batch loss : 0.6347576379776001
# Epoch(0/1) : Batch no (94/782) : Batch loss : 0.822963297367096
# Epoch(0/1) : Batch no (95/782) : Batch loss : 1.1008514165878296
# Epoch(0/1) : Batch no (96/782) : Batch loss : 0.9026739001274109
# Epoch(0/1) : Batch no (97/782) : Batch loss : 0.5995911955833435
# Epoch(0/1) : Batch no (98/782) : Batch loss : 0.5791123509407043
# Epoch(0/1) : Batch no (99/782) : Batch loss : 0.5636937022209167
# Epoch(0/1) : Batch no (100/782) : Batch loss : 0.4330233931541443
# Epoch(0/1) : Batch no (101/782) : Batch loss : 0.7502676844596863
# Epoch(0/1) : Batch no (102/782) : Batch loss : 0.8035179972648621
# Epoch(0/1) : Batch no (103/782) : Batch loss : 0.827328085899353
# Epoch(0/1) : Batch no (104/782) : Batch loss : 0.7065699100494385
# Epoch(0/1) : Batch no (105/782) : Batch loss : 1.0108165740966797
# Epoch(0/1) : Batch no (106/782) : Batch loss : 0.80921870470047
# Epoch(0/1) : Batch no (107/782) : Batch loss : 0.8913599252700806
# Epoch(0/1) : Batch no (108/782) : Batch loss : 0.7613288164138794
# Epoch(0/1) : Batch no (109/782) : Batch loss : 0.9055142402648926
# Epoch(0/1) : Batch no (110/782) : Batch loss : 0.8296770453453064
# Epoch(0/1) : Batch no (111/782) : Batch loss : 0.8793410658836365
# Epoch(0/1) : Batch no (112/782) : Batch loss : 0.9158141613006592
# Epoch(0/1) : Batch no (113/782) : Batch loss : 0.6562147736549377
# Epoch(0/1) : Batch no (114/782) : Batch loss : 0.857732355594635
# Epoch(0/1) : Batch no (115/782) : Batch loss : 0.9260272979736328
# Epoch(0/1) : Batch no (116/782) : Batch loss : 0.5723363161087036
# Epoch(0/1) : Batch no (117/782) : Batch loss : 0.6292100548744202
# Epoch(0/1) : Batch no (118/782) : Batch loss : 0.7967914342880249
# Epoch(0/1) : Batch no (119/782) : Batch loss : 0.9764841794967651
# Epoch(0/1) : Batch no (120/782) : Batch loss : 0.7933904528617859
# Epoch(0/1) : Batch no (121/782) : Batch loss : 0.6380992531776428
# Epoch(0/1) : Batch no (122/782) : Batch loss : 0.937710702419281
# Epoch(0/1) : Batch no (123/782) : Batch loss : 0.6537129878997803
# Epoch(0/1) : Batch no (124/782) : Batch loss : 0.7001379728317261
# Epoch(0/1) : Batch no (125/782) : Batch loss : 0.6787403225898743
# Epoch(0/1) : Batch no (126/782) : Batch loss : 0.4585043787956238
# Epoch(0/1) : Batch no (127/782) : Batch loss : 0.7500860095024109
# Epoch(0/1) : Batch no (128/782) : Batch loss : 0.9160252213478088
# Epoch(0/1) : Batch no (129/782) : Batch loss : 0.5914792418479919
# Epoch(0/1) : Batch no (130/782) : Batch loss : 0.7532531023025513
# Epoch(0/1) : Batch no (131/782) : Batch loss : 0.8293279409408569
# Epoch(0/1) : Batch no (132/782) : Batch loss : 0.6729949116706848
# Epoch(0/1) : Batch no (133/782) : Batch loss : 0.6668499112129211
# Epoch(0/1) : Batch no (134/782) : Batch loss : 0.6264305114746094
# Epoch(0/1) : Batch no (135/782) : Batch loss : 0.5401590466499329
# Epoch(0/1) : Batch no (136/782) : Batch loss : 0.843113899230957
# Epoch(0/1) : Batch no (137/782) : Batch loss : 0.7971338033676147
# Epoch(0/1) : Batch no (138/782) : Batch loss : 0.5676789283752441
# Epoch(0/1) : Batch no (139/782) : Batch loss : 0.4491463899612427
# Epoch(0/1) : Batch no (140/782) : Batch loss : 0.6157345771789551
# Epoch(0/1) : Batch no (141/782) : Batch loss : 0.8230082988739014
# Epoch(0/1) : Batch no (142/782) : Batch loss : 0.9084334969520569
# Epoch(0/1) : Batch no (143/782) : Batch loss : 0.7479225993156433
# Epoch(0/1) : Batch no (144/782) : Batch loss : 0.6192460656166077
# Epoch(0/1) : Batch no (145/782) : Batch loss : 0.5017436742782593
# Epoch(0/1) : Batch no (146/782) : Batch loss : 0.9685526490211487
# Epoch(0/1) : Batch no (147/782) : Batch loss : 0.8727452754974365
# Epoch(0/1) : Batch no (148/782) : Batch loss : 0.5638048648834229
# Epoch(0/1) : Batch no (149/782) : Batch loss : 0.5667199492454529
# Epoch(0/1) : Batch no (150/782) : Batch loss : 0.9540103673934937
# Epoch(0/1) : Batch no (151/782) : Batch loss : 0.8976210355758667
# Epoch(0/1) : Batch no (152/782) : Batch loss : 0.7950020432472229
# Epoch(0/1) : Batch no (153/782) : Batch loss : 0.7248620986938477
# Epoch(0/1) : Batch no (154/782) : Batch loss : 0.6249150633811951
# Epoch(0/1) : Batch no (155/782) : Batch loss : 0.6401859521865845
# Epoch(0/1) : Batch no (156/782) : Batch loss : 0.5248852968215942
# Epoch(0/1) : Batch no (157/782) : Batch loss : 0.6350104212760925
# Epoch(0/1) : Batch no (158/782) : Batch loss : 0.45615270733833313
# Epoch(0/1) : Batch no (159/782) : Batch loss : 0.6920386552810669
# Epoch(0/1) : Batch no (160/782) : Batch loss : 1.0624316930770874
# Epoch(0/1) : Batch no (161/782) : Batch loss : 0.4405982196331024
# Epoch(0/1) : Batch no (162/782) : Batch loss : 0.7318847179412842
# Epoch(0/1) : Batch no (163/782) : Batch loss : 0.6188471913337708
# Epoch(0/1) : Batch no (164/782) : Batch loss : 0.7087395191192627
# Epoch(0/1) : Batch no (165/782) : Batch loss : 0.5455018281936646
# Epoch(0/1) : Batch no (166/782) : Batch loss : 0.6629108190536499
# Epoch(0/1) : Batch no (167/782) : Batch loss : 0.8707507252693176
# Epoch(0/1) : Batch no (168/782) : Batch loss : 0.8611288070678711
# Epoch(0/1) : Batch no (169/782) : Batch loss : 0.795395016670227
# Epoch(0/1) : Batch no (170/782) : Batch loss : 0.6721138954162598
# Epoch(0/1) : Batch no (171/782) : Batch loss : 0.7485737204551697
# Epoch(0/1) : Batch no (172/782) : Batch loss : 0.6941332817077637
# Epoch(0/1) : Batch no (173/782) : Batch loss : 0.7522648572921753
# Epoch(0/1) : Batch no (174/782) : Batch loss : 0.4912112057209015
# Epoch(0/1) : Batch no (175/782) : Batch loss : 0.7370486259460449
# Epoch(0/1) : Batch no (176/782) : Batch loss : 0.951774001121521
# Epoch(0/1) : Batch no (177/782) : Batch loss : 0.7425951957702637
# Epoch(0/1) : Batch no (178/782) : Batch loss : 0.4062909781932831
# Epoch(0/1) : Batch no (179/782) : Batch loss : 0.6735860109329224
# Epoch(0/1) : Batch no (180/782) : Batch loss : 0.7114959359169006
# Epoch(0/1) : Batch no (181/782) : Batch loss : 0.747369110584259
# Epoch(0/1) : Batch no (182/782) : Batch loss : 0.7329120635986328
# Epoch(0/1) : Batch no (183/782) : Batch loss : 0.595458984375
# Epoch(0/1) : Batch no (184/782) : Batch loss : 0.5483130812644958
# Epoch(0/1) : Batch no (185/782) : Batch loss : 0.6251569986343384
# Epoch(0/1) : Batch no (186/782) : Batch loss : 0.786352276802063
# Epoch(0/1) : Batch no (187/782) : Batch loss : 0.4529656767845154
# Epoch(0/1) : Batch no (188/782) : Batch loss : 0.7409924864768982
# Epoch(0/1) : Batch no (189/782) : Batch loss : 0.7808653116226196
# Epoch(0/1) : Batch no (190/782) : Batch loss : 0.7267696261405945
# Epoch(0/1) : Batch no (191/782) : Batch loss : 0.8094550371170044
# Epoch(0/1) : Batch no (192/782) : Batch loss : 0.9671114683151245
# Epoch(0/1) : Batch no (193/782) : Batch loss : 0.6031162142753601
# Epoch(0/1) : Batch no (194/782) : Batch loss : 0.7136752605438232
# Epoch(0/1) : Batch no (195/782) : Batch loss : 0.613380491733551
# Epoch(0/1) : Batch no (196/782) : Batch loss : 0.7916611433029175
# Epoch(0/1) : Batch no (197/782) : Batch loss : 0.6459840536117554
# Epoch(0/1) : Batch no (198/782) : Batch loss : 0.6343405246734619
# Epoch(0/1) : Batch no (199/782) : Batch loss : 0.677272617816925
# Epoch(0/1) : Batch no (200/782) : Batch loss : 0.6361144185066223
# Epoch(0/1) : Batch no (201/782) : Batch loss : 0.7593616843223572
# Epoch(0/1) : Batch no (202/782) : Batch loss : 0.913202166557312
# Epoch(0/1) : Batch no (203/782) : Batch loss : 0.7760434746742249
# Epoch(0/1) : Batch no (204/782) : Batch loss : 0.5710793137550354
# Epoch(0/1) : Batch no (205/782) : Batch loss : 0.6170164346694946
# Epoch(0/1) : Batch no (206/782) : Batch loss : 0.9447352886199951
# Epoch(0/1) : Batch no (207/782) : Batch loss : 0.4612865746021271
# Epoch(0/1) : Batch no (208/782) : Batch loss : 0.554618239402771
# Epoch(0/1) : Batch no (209/782) : Batch loss : 0.6660557389259338
# Epoch(0/1) : Batch no (210/782) : Batch loss : 0.6105840802192688
# Epoch(0/1) : Batch no (211/782) : Batch loss : 0.6603876352310181
# Epoch(0/1) : Batch no (212/782) : Batch loss : 0.728285014629364
# Epoch(0/1) : Batch no (213/782) : Batch loss : 0.8204442262649536
# Epoch(0/1) : Batch no (214/782) : Batch loss : 0.7255700826644897
# Epoch(0/1) : Batch no (215/782) : Batch loss : 0.9203273057937622
# Epoch(0/1) : Batch no (216/782) : Batch loss : 0.7747501730918884
# Epoch(0/1) : Batch no (217/782) : Batch loss : 0.7757325768470764
# Epoch(0/1) : Batch no (218/782) : Batch loss : 0.759458601474762
# Epoch(0/1) : Batch no (219/782) : Batch loss : 0.5928245782852173
# Epoch(0/1) : Batch no (220/782) : Batch loss : 0.8800552487373352
# Epoch(0/1) : Batch no (221/782) : Batch loss : 1.0320565700531006
# Epoch(0/1) : Batch no (222/782) : Batch loss : 0.3962673842906952
# Epoch(0/1) : Batch no (223/782) : Batch loss : 0.6976693868637085
# Epoch(0/1) : Batch no (224/782) : Batch loss : 0.8622307181358337
# Epoch(0/1) : Batch no (225/782) : Batch loss : 0.5271522998809814
# Epoch(0/1) : Batch no (226/782) : Batch loss : 0.9023396372795105
# Epoch(0/1) : Batch no (227/782) : Batch loss : 0.6028243899345398
# Epoch(0/1) : Batch no (228/782) : Batch loss : 0.7721935510635376
# Epoch(0/1) : Batch no (229/782) : Batch loss : 0.573226273059845
# Epoch(0/1) : Batch no (230/782) : Batch loss : 0.6825408339500427
# Epoch(0/1) : Batch no (231/782) : Batch loss : 0.6728143692016602
# Epoch(0/1) : Batch no (232/782) : Batch loss : 0.5616941452026367
# Epoch(0/1) : Batch no (233/782) : Batch loss : 0.8541588187217712
# Epoch(0/1) : Batch no (234/782) : Batch loss : 0.6483096480369568
# Epoch(0/1) : Batch no (235/782) : Batch loss : 0.5588757395744324
# Epoch(0/1) : Batch no (236/782) : Batch loss : 0.569822371006012
# Epoch(0/1) : Batch no (237/782) : Batch loss : 0.6379651427268982
# Epoch(0/1) : Batch no (238/782) : Batch loss : 0.5853410363197327
# Epoch(0/1) : Batch no (239/782) : Batch loss : 0.47825098037719727
# Epoch(0/1) : Batch no (240/782) : Batch loss : 0.5152390003204346
# Epoch(0/1) : Batch no (241/782) : Batch loss : 0.839647650718689
# Epoch(0/1) : Batch no (242/782) : Batch loss : 0.781956672668457
# Epoch(0/1) : Batch no (243/782) : Batch loss : 0.8087819814682007
# Epoch(0/1) : Batch no (244/782) : Batch loss : 0.8216863870620728
# Epoch(0/1) : Batch no (245/782) : Batch loss : 0.6879519820213318
# Epoch(0/1) : Batch no (246/782) : Batch loss : 0.7730247378349304
# Epoch(0/1) : Batch no (247/782) : Batch loss : 0.804095983505249
# Epoch(0/1) : Batch no (248/782) : Batch loss : 0.621313750743866
# Epoch(0/1) : Batch no (249/782) : Batch loss : 0.7162229418754578
# Epoch(0/1) : Batch no (250/782) : Batch loss : 0.934531569480896
# Epoch(0/1) : Batch no (251/782) : Batch loss : 0.8246351480484009
# Epoch(0/1) : Batch no (252/782) : Batch loss : 0.8852685689926147
# Epoch(0/1) : Batch no (253/782) : Batch loss : 0.8869636058807373
# Epoch(0/1) : Batch no (254/782) : Batch loss : 0.7006964683532715
# Epoch(0/1) : Batch no (255/782) : Batch loss : 0.8675516247749329
# Epoch(0/1) : Batch no (256/782) : Batch loss : 0.5982047319412231
# Epoch(0/1) : Batch no (257/782) : Batch loss : 0.8785371780395508
# Epoch(0/1) : Batch no (258/782) : Batch loss : 0.5578811764717102
# Epoch(0/1) : Batch no (259/782) : Batch loss : 0.7939379215240479
# Epoch(0/1) : Batch no (260/782) : Batch loss : 0.6112104654312134
# Epoch(0/1) : Batch no (261/782) : Batch loss : 0.680712878704071
# Epoch(0/1) : Batch no (262/782) : Batch loss : 0.7462055683135986
# Epoch(0/1) : Batch no (263/782) : Batch loss : 0.7859641909599304
# Epoch(0/1) : Batch no (264/782) : Batch loss : 0.5466578602790833
# Epoch(0/1) : Batch no (265/782) : Batch loss : 0.4535885751247406
# Epoch(0/1) : Batch no (266/782) : Batch loss : 0.7071489095687866
# Epoch(0/1) : Batch no (267/782) : Batch loss : 0.6706421971321106
# Epoch(0/1) : Batch no (268/782) : Batch loss : 0.7263069748878479
# Epoch(0/1) : Batch no (269/782) : Batch loss : 0.7774566411972046
# Epoch(0/1) : Batch no (270/782) : Batch loss : 0.5799842476844788
# Epoch(0/1) : Batch no (271/782) : Batch loss : 0.635369598865509
# Epoch(0/1) : Batch no (272/782) : Batch loss : 0.7745977640151978
# Epoch(0/1) : Batch no (273/782) : Batch loss : 0.7638096213340759
# Epoch(0/1) : Batch no (274/782) : Batch loss : 0.4855055510997772
# Epoch(0/1) : Batch no (275/782) : Batch loss : 0.8075883984565735
# Epoch(0/1) : Batch no (276/782) : Batch loss : 0.5730621218681335
# Epoch(0/1) : Batch no (277/782) : Batch loss : 0.7058107256889343
# Epoch(0/1) : Batch no (278/782) : Batch loss : 0.6590014696121216
# Epoch(0/1) : Batch no (279/782) : Batch loss : 0.7690567374229431
# Epoch(0/1) : Batch no (280/782) : Batch loss : 0.7470970749855042
# Epoch(0/1) : Batch no (281/782) : Batch loss : 0.6042695045471191
# Epoch(0/1) : Batch no (282/782) : Batch loss : 1.0364023447036743
# Epoch(0/1) : Batch no (283/782) : Batch loss : 0.5582612156867981
# Epoch(0/1) : Batch no (284/782) : Batch loss : 0.5888792872428894
# Epoch(0/1) : Batch no (285/782) : Batch loss : 0.7549969553947449
# Epoch(0/1) : Batch no (286/782) : Batch loss : 0.8374599814414978
# Epoch(0/1) : Batch no (287/782) : Batch loss : 0.6115541458129883
# Epoch(0/1) : Batch no (288/782) : Batch loss : 0.6328242421150208
# Epoch(0/1) : Batch no (289/782) : Batch loss : 0.5994833707809448
# Epoch(0/1) : Batch no (290/782) : Batch loss : 0.6372145414352417
# Epoch(0/1) : Batch no (291/782) : Batch loss : 0.6854583024978638
# Epoch(0/1) : Batch no (292/782) : Batch loss : 0.6714946627616882
# Epoch(0/1) : Batch no (293/782) : Batch loss : 0.6968024373054504
# Epoch(0/1) : Batch no (294/782) : Batch loss : 0.6345176696777344
# Epoch(0/1) : Batch no (295/782) : Batch loss : 0.7594532370567322
# Epoch(0/1) : Batch no (296/782) : Batch loss : 0.905056893825531
# Epoch(0/1) : Batch no (297/782) : Batch loss : 0.7006495594978333
# Epoch(0/1) : Batch no (298/782) : Batch loss : 0.696617603302002
# Epoch(0/1) : Batch no (299/782) : Batch loss : 0.7899733781814575
# Epoch(0/1) : Batch no (300/782) : Batch loss : 0.7581989765167236
# Epoch(0/1) : Batch no (301/782) : Batch loss : 0.7955945730209351
# Epoch(0/1) : Batch no (302/782) : Batch loss : 0.9229472875595093
# Epoch(0/1) : Batch no (303/782) : Batch loss : 0.8132510781288147
# Epoch(0/1) : Batch no (304/782) : Batch loss : 0.49311962723731995
# Epoch(0/1) : Batch no (305/782) : Batch loss : 0.6686179041862488
# Epoch(0/1) : Batch no (306/782) : Batch loss : 0.6040067076683044
# Epoch(0/1) : Batch no (307/782) : Batch loss : 0.8926214575767517
# Epoch(0/1) : Batch no (308/782) : Batch loss : 0.6395926475524902
# Epoch(0/1) : Batch no (309/782) : Batch loss : 0.6241115927696228
# Epoch(0/1) : Batch no (310/782) : Batch loss : 0.6710401177406311
# Epoch(0/1) : Batch no (311/782) : Batch loss : 0.6394727826118469
# Epoch(0/1) : Batch no (312/782) : Batch loss : 0.6839330792427063
# Epoch(0/1) : Batch no (313/782) : Batch loss : 0.6250860095024109
# Epoch(0/1) : Batch no (314/782) : Batch loss : 0.7265402674674988
# Epoch(0/1) : Batch no (315/782) : Batch loss : 0.6495408415794373
# Epoch(0/1) : Batch no (316/782) : Batch loss : 0.657182514667511
# Epoch(0/1) : Batch no (317/782) : Batch loss : 0.864411473274231
# Epoch(0/1) : Batch no (318/782) : Batch loss : 0.6942008137702942
# Epoch(0/1) : Batch no (319/782) : Batch loss : 0.81004798412323
# Epoch(0/1) : Batch no (320/782) : Batch loss : 0.7363067865371704
# Epoch(0/1) : Batch no (321/782) : Batch loss : 0.6077336072921753
# Epoch(0/1) : Batch no (322/782) : Batch loss : 0.6564833521842957
# Epoch(0/1) : Batch no (323/782) : Batch loss : 0.8152080178260803
# Epoch(0/1) : Batch no (324/782) : Batch loss : 0.7800812125205994
# Epoch(0/1) : Batch no (325/782) : Batch loss : 0.7599488496780396
# Epoch(0/1) : Batch no (326/782) : Batch loss : 0.7333399653434753
# Epoch(0/1) : Batch no (327/782) : Batch loss : 0.8092042803764343
# Epoch(0/1) : Batch no (328/782) : Batch loss : 0.6002092361450195
# Epoch(0/1) : Batch no (329/782) : Batch loss : 0.7777158617973328
# Epoch(0/1) : Batch no (330/782) : Batch loss : 0.7457495331764221
# Epoch(0/1) : Batch no (331/782) : Batch loss : 0.554092288017273
# Epoch(0/1) : Batch no (332/782) : Batch loss : 0.5353121757507324
# Epoch(0/1) : Batch no (333/782) : Batch loss : 0.5236656069755554
# Epoch(0/1) : Batch no (334/782) : Batch loss : 0.8306728005409241
# Epoch(0/1) : Batch no (335/782) : Batch loss : 0.7590998411178589
# Epoch(0/1) : Batch no (336/782) : Batch loss : 0.5465070605278015
# Epoch(0/1) : Batch no (337/782) : Batch loss : 0.6185149550437927
# Epoch(0/1) : Batch no (338/782) : Batch loss : 0.9714686870574951
# Epoch(0/1) : Batch no (339/782) : Batch loss : 0.5584059357643127
# Epoch(0/1) : Batch no (340/782) : Batch loss : 0.8032189011573792
# Epoch(0/1) : Batch no (341/782) : Batch loss : 0.48169997334480286
# Epoch(0/1) : Batch no (342/782) : Batch loss : 0.6854371428489685
# Epoch(0/1) : Batch no (343/782) : Batch loss : 0.6269789934158325
# Epoch(0/1) : Batch no (344/782) : Batch loss : 0.7650918960571289
# Epoch(0/1) : Batch no (345/782) : Batch loss : 0.756260871887207
# Epoch(0/1) : Batch no (346/782) : Batch loss : 0.5452492237091064
# Epoch(0/1) : Batch no (347/782) : Batch loss : 0.6071503758430481
# Epoch(0/1) : Batch no (348/782) : Batch loss : 0.5962672233581543
# Epoch(0/1) : Batch no (349/782) : Batch loss : 0.5867431163787842
# Epoch(0/1) : Batch no (350/782) : Batch loss : 0.5458385348320007
# Epoch(0/1) : Batch no (351/782) : Batch loss : 0.48007434606552124
# Epoch(0/1) : Batch no (352/782) : Batch loss : 0.6393550038337708
# Epoch(0/1) : Batch no (353/782) : Batch loss : 0.6249994039535522
# Epoch(0/1) : Batch no (354/782) : Batch loss : 0.7111214399337769
# Epoch(0/1) : Batch no (355/782) : Batch loss : 0.43290719389915466
# Epoch(0/1) : Batch no (356/782) : Batch loss : 0.6093922257423401
# Epoch(0/1) : Batch no (357/782) : Batch loss : 0.7005401253700256
# Epoch(0/1) : Batch no (358/782) : Batch loss : 0.47723060846328735
# Epoch(0/1) : Batch no (359/782) : Batch loss : 0.7469459176063538
# Epoch(0/1) : Batch no (360/782) : Batch loss : 0.562876284122467
# Epoch(0/1) : Batch no (361/782) : Batch loss : 0.7962042689323425
# Epoch(0/1) : Batch no (362/782) : Batch loss : 0.5364866852760315
# Epoch(0/1) : Batch no (363/782) : Batch loss : 0.4450247287750244
# Epoch(0/1) : Batch no (364/782) : Batch loss : 0.7002201676368713
# Epoch(0/1) : Batch no (365/782) : Batch loss : 0.5354001522064209
# Epoch(0/1) : Batch no (366/782) : Batch loss : 0.9480385780334473
# Epoch(0/1) : Batch no (367/782) : Batch loss : 0.674950361251831
# Epoch(0/1) : Batch no (368/782) : Batch loss : 0.5634332895278931
# Epoch(0/1) : Batch no (369/782) : Batch loss : 0.6389954686164856
# Epoch(0/1) : Batch no (370/782) : Batch loss : 0.9383106827735901
# Epoch(0/1) : Batch no (371/782) : Batch loss : 0.5145542025566101
# Epoch(0/1) : Batch no (372/782) : Batch loss : 0.5413658618927002
# Epoch(0/1) : Batch no (373/782) : Batch loss : 0.4651997685432434
# Epoch(0/1) : Batch no (374/782) : Batch loss : 0.3741128742694855
# Epoch(0/1) : Batch no (375/782) : Batch loss : 0.7453455328941345
# Epoch(0/1) : Batch no (376/782) : Batch loss : 0.5050210952758789
# Epoch(0/1) : Batch no (377/782) : Batch loss : 0.5571094155311584
# Epoch(0/1) : Batch no (378/782) : Batch loss : 0.8332511782646179
# Epoch(0/1) : Batch no (379/782) : Batch loss : 0.6918987035751343
# Epoch(0/1) : Batch no (380/782) : Batch loss : 0.7308693528175354
# Epoch(0/1) : Batch no (381/782) : Batch loss : 0.8279620409011841
# Epoch(0/1) : Batch no (382/782) : Batch loss : 0.5594151616096497
# Epoch(0/1) : Batch no (383/782) : Batch loss : 0.7753683924674988
# Epoch(0/1) : Batch no (384/782) : Batch loss : 0.8834129571914673
# Epoch(0/1) : Batch no (385/782) : Batch loss : 0.7547266483306885
# Epoch(0/1) : Batch no (386/782) : Batch loss : 0.6032585501670837
# Epoch(0/1) : Batch no (387/782) : Batch loss : 0.5302030444145203
# Epoch(0/1) : Batch no (388/782) : Batch loss : 0.6742671132087708
# Epoch(0/1) : Batch no (389/782) : Batch loss : 0.7198418378829956
# Epoch(0/1) : Batch no (390/782) : Batch loss : 0.8952995538711548
# Epoch(0/1) : Batch no (391/782) : Batch loss : 0.7475792169570923
# Epoch(0/1) : Batch no (392/782) : Batch loss : 0.6284501552581787
# Epoch(0/1) : Batch no (393/782) : Batch loss : 0.6236898303031921
# Epoch(0/1) : Batch no (394/782) : Batch loss : 0.7306450605392456
# Epoch(0/1) : Batch no (395/782) : Batch loss : 0.6109147071838379
# Epoch(0/1) : Batch no (396/782) : Batch loss : 0.6234953999519348
# Epoch(0/1) : Batch no (397/782) : Batch loss : 0.6464235186576843
# Epoch(0/1) : Batch no (398/782) : Batch loss : 0.5463166236877441
# Epoch(0/1) : Batch no (399/782) : Batch loss : 0.6194002628326416
# Epoch(0/1) : Batch no (400/782) : Batch loss : 0.8273958563804626
# Epoch(0/1) : Batch no (401/782) : Batch loss : 0.6804347634315491
# Epoch(0/1) : Batch no (402/782) : Batch loss : 0.6421313285827637
# Epoch(0/1) : Batch no (403/782) : Batch loss : 0.8675056099891663
# Epoch(0/1) : Batch no (404/782) : Batch loss : 0.5168580412864685
# Epoch(0/1) : Batch no (405/782) : Batch loss : 0.7820109128952026
# Epoch(0/1) : Batch no (406/782) : Batch loss : 0.7231789231300354
# Epoch(0/1) : Batch no (407/782) : Batch loss : 0.673745334148407
# Epoch(0/1) : Batch no (408/782) : Batch loss : 0.6975353360176086
# Epoch(0/1) : Batch no (409/782) : Batch loss : 0.6888827681541443
# Epoch(0/1) : Batch no (410/782) : Batch loss : 0.5570265650749207
# Epoch(0/1) : Batch no (411/782) : Batch loss : 0.6098712682723999
# Epoch(0/1) : Batch no (412/782) : Batch loss : 0.7281637191772461
# Epoch(0/1) : Batch no (413/782) : Batch loss : 0.7573155760765076
# Epoch(0/1) : Batch no (414/782) : Batch loss : 0.6182471513748169
# Epoch(0/1) : Batch no (415/782) : Batch loss : 0.6748306751251221
# Epoch(0/1) : Batch no (416/782) : Batch loss : 0.6763027906417847
# Epoch(0/1) : Batch no (417/782) : Batch loss : 0.6768219470977783
# Epoch(0/1) : Batch no (418/782) : Batch loss : 0.8186336159706116
# Epoch(0/1) : Batch no (419/782) : Batch loss : 0.6014774441719055
# Epoch(0/1) : Batch no (420/782) : Batch loss : 0.6454145312309265
# Epoch(0/1) : Batch no (421/782) : Batch loss : 0.7269494533538818
# Epoch(0/1) : Batch no (422/782) : Batch loss : 0.8603689074516296
# Epoch(0/1) : Batch no (423/782) : Batch loss : 0.939532995223999
# Epoch(0/1) : Batch no (424/782) : Batch loss : 0.5362362861633301
# Epoch(0/1) : Batch no (425/782) : Batch loss : 0.8607695698738098
# Epoch(0/1) : Batch no (426/782) : Batch loss : 0.8859051465988159
# Epoch(0/1) : Batch no (427/782) : Batch loss : 0.4922201931476593
# Epoch(0/1) : Batch no (428/782) : Batch loss : 0.5381269454956055
# Epoch(0/1) : Batch no (429/782) : Batch loss : 0.5716598629951477
# Epoch(0/1) : Batch no (430/782) : Batch loss : 0.4903714954853058
# Epoch(0/1) : Batch no (431/782) : Batch loss : 0.9280391335487366
# Epoch(0/1) : Batch no (432/782) : Batch loss : 0.7682774066925049
# Epoch(0/1) : Batch no (433/782) : Batch loss : 0.6941015124320984
# Epoch(0/1) : Batch no (434/782) : Batch loss : 0.7120928168296814
# Epoch(0/1) : Batch no (435/782) : Batch loss : 0.6736629009246826
# Epoch(0/1) : Batch no (436/782) : Batch loss : 0.5900239944458008
# Epoch(0/1) : Batch no (437/782) : Batch loss : 0.511615514755249
# Epoch(0/1) : Batch no (438/782) : Batch loss : 0.8403168320655823
# Epoch(0/1) : Batch no (439/782) : Batch loss : 0.6878425478935242
# Epoch(0/1) : Batch no (440/782) : Batch loss : 0.7317425608634949
# Epoch(0/1) : Batch no (441/782) : Batch loss : 0.7204567193984985
# Epoch(0/1) : Batch no (442/782) : Batch loss : 0.5624741911888123
# Epoch(0/1) : Batch no (443/782) : Batch loss : 0.8317881226539612
# Epoch(0/1) : Batch no (444/782) : Batch loss : 0.7082065939903259
# Epoch(0/1) : Batch no (445/782) : Batch loss : 0.8004508018493652
# Epoch(0/1) : Batch no (446/782) : Batch loss : 0.9364504218101501
# Epoch(0/1) : Batch no (447/782) : Batch loss : 0.5664293766021729
# Epoch(0/1) : Batch no (448/782) : Batch loss : 0.645609974861145
# Epoch(0/1) : Batch no (449/782) : Batch loss : 0.7324799299240112
# Epoch(0/1) : Batch no (450/782) : Batch loss : 0.7434255480766296
# Epoch(0/1) : Batch no (451/782) : Batch loss : 0.6917465925216675
# Epoch(0/1) : Batch no (452/782) : Batch loss : 0.6741215586662292
# Epoch(0/1) : Batch no (453/782) : Batch loss : 0.6695864796638489
# Epoch(0/1) : Batch no (454/782) : Batch loss : 0.6941291093826294
# Epoch(0/1) : Batch no (455/782) : Batch loss : 0.6725099682807922
# Epoch(0/1) : Batch no (456/782) : Batch loss : 0.7854491472244263
# Epoch(0/1) : Batch no (457/782) : Batch loss : 0.5446839928627014
# Epoch(0/1) : Batch no (458/782) : Batch loss : 0.5030065178871155
# Epoch(0/1) : Batch no (459/782) : Batch loss : 0.5232770442962646
# Epoch(0/1) : Batch no (460/782) : Batch loss : 0.8263963460922241
# Epoch(0/1) : Batch no (461/782) : Batch loss : 0.5566043853759766
# Epoch(0/1) : Batch no (462/782) : Batch loss : 0.8316320776939392
# Epoch(0/1) : Batch no (463/782) : Batch loss : 0.5085180401802063
# Epoch(0/1) : Batch no (464/782) : Batch loss : 0.8254107236862183
# Epoch(0/1) : Batch no (465/782) : Batch loss : 0.512345016002655
# Epoch(0/1) : Batch no (466/782) : Batch loss : 0.931348979473114
# Epoch(0/1) : Batch no (467/782) : Batch loss : 0.6921719908714294
# Epoch(0/1) : Batch no (468/782) : Batch loss : 0.7888126373291016
# Epoch(0/1) : Batch no (469/782) : Batch loss : 0.7763230204582214
# Epoch(0/1) : Batch no (470/782) : Batch loss : 0.7470692992210388
# Epoch(0/1) : Batch no (471/782) : Batch loss : 0.7242340445518494
# Epoch(0/1) : Batch no (472/782) : Batch loss : 0.7036768198013306
# Epoch(0/1) : Batch no (473/782) : Batch loss : 0.38029447197914124
# Epoch(0/1) : Batch no (474/782) : Batch loss : 0.8260557055473328
# Epoch(0/1) : Batch no (475/782) : Batch loss : 0.6455775499343872
# Epoch(0/1) : Batch no (476/782) : Batch loss : 0.5519149303436279
# Epoch(0/1) : Batch no (477/782) : Batch loss : 0.6769317984580994
# Epoch(0/1) : Batch no (478/782) : Batch loss : 0.7691890001296997
# Epoch(0/1) : Batch no (479/782) : Batch loss : 0.6851012110710144
# Epoch(0/1) : Batch no (480/782) : Batch loss : 0.8019198179244995
# Epoch(0/1) : Batch no (481/782) : Batch loss : 0.6487507224082947
# Epoch(0/1) : Batch no (482/782) : Batch loss : 0.8378754258155823
# Epoch(0/1) : Batch no (483/782) : Batch loss : 0.8316982388496399
# Epoch(0/1) : Batch no (484/782) : Batch loss : 0.7012035250663757
# Epoch(0/1) : Batch no (485/782) : Batch loss : 0.6898627281188965
# Epoch(0/1) : Batch no (486/782) : Batch loss : 0.6976155042648315
# Epoch(0/1) : Batch no (487/782) : Batch loss : 0.6365779042243958
# Epoch(0/1) : Batch no (488/782) : Batch loss : 0.7021448016166687
# Epoch(0/1) : Batch no (489/782) : Batch loss : 0.48556679487228394
# Epoch(0/1) : Batch no (490/782) : Batch loss : 0.5799490213394165
# Epoch(0/1) : Batch no (491/782) : Batch loss : 0.5870450735092163
# Epoch(0/1) : Batch no (492/782) : Batch loss : 0.4999261796474457
# Epoch(0/1) : Batch no (493/782) : Batch loss : 0.5567497611045837
# Epoch(0/1) : Batch no (494/782) : Batch loss : 0.7058615684509277
# Epoch(0/1) : Batch no (495/782) : Batch loss : 0.542254626750946
# Epoch(0/1) : Batch no (496/782) : Batch loss : 0.643040120601654
# Epoch(0/1) : Batch no (497/782) : Batch loss : 0.5519710183143616
# Epoch(0/1) : Batch no (498/782) : Batch loss : 0.576998233795166
# Epoch(0/1) : Batch no (499/782) : Batch loss : 0.8841339945793152
# Epoch(0/1) : Batch no (500/782) : Batch loss : 0.6823177933692932
# Epoch(0/1) : Batch no (501/782) : Batch loss : 0.6833247542381287
# Epoch(0/1) : Batch no (502/782) : Batch loss : 0.6888445615768433
# Epoch(0/1) : Batch no (503/782) : Batch loss : 0.7008028626441956
# Epoch(0/1) : Batch no (504/782) : Batch loss : 0.8415738940238953
# Epoch(0/1) : Batch no (505/782) : Batch loss : 0.7571229934692383
# Epoch(0/1) : Batch no (506/782) : Batch loss : 0.6161277890205383
# Epoch(0/1) : Batch no (507/782) : Batch loss : 0.7027698755264282
# Epoch(0/1) : Batch no (508/782) : Batch loss : 0.5199012160301208
# Epoch(0/1) : Batch no (509/782) : Batch loss : 0.7776284217834473
# Epoch(0/1) : Batch no (510/782) : Batch loss : 0.5821000337600708
# Epoch(0/1) : Batch no (511/782) : Batch loss : 0.5813217759132385
# Epoch(0/1) : Batch no (512/782) : Batch loss : 0.587624728679657
# Epoch(0/1) : Batch no (513/782) : Batch loss : 0.7562178373336792
# Epoch(0/1) : Batch no (514/782) : Batch loss : 0.6696907877922058
# Epoch(0/1) : Batch no (515/782) : Batch loss : 0.5334362387657166
# Epoch(0/1) : Batch no (516/782) : Batch loss : 0.6015937924385071
# Epoch(0/1) : Batch no (517/782) : Batch loss : 0.7764071226119995
# Epoch(0/1) : Batch no (518/782) : Batch loss : 0.45181897282600403
# Epoch(0/1) : Batch no (519/782) : Batch loss : 0.5500044226646423
# Epoch(0/1) : Batch no (520/782) : Batch loss : 0.4245111048221588
# Epoch(0/1) : Batch no (521/782) : Batch loss : 0.5859009027481079
# Epoch(0/1) : Batch no (522/782) : Batch loss : 0.6828294992446899
# Epoch(0/1) : Batch no (523/782) : Batch loss : 0.5723724365234375
# Epoch(0/1) : Batch no (524/782) : Batch loss : 0.5837802290916443
# Epoch(0/1) : Batch no (525/782) : Batch loss : 0.8856382369995117
# Epoch(0/1) : Batch no (526/782) : Batch loss : 0.6194583773612976
# Epoch(0/1) : Batch no (527/782) : Batch loss : 0.702968418598175
# Epoch(0/1) : Batch no (528/782) : Batch loss : 0.4287101924419403
# Epoch(0/1) : Batch no (529/782) : Batch loss : 0.6540661454200745
# Epoch(0/1) : Batch no (530/782) : Batch loss : 0.7255750894546509
# Epoch(0/1) : Batch no (531/782) : Batch loss : 0.6422641277313232
# Epoch(0/1) : Batch no (532/782) : Batch loss : 0.6549116969108582
# Epoch(0/1) : Batch no (533/782) : Batch loss : 0.6331174373626709
# Epoch(0/1) : Batch no (534/782) : Batch loss : 0.5518049597740173
# Epoch(0/1) : Batch no (535/782) : Batch loss : 0.6563477516174316
# Epoch(0/1) : Batch no (536/782) : Batch loss : 0.6774703860282898
# Epoch(0/1) : Batch no (537/782) : Batch loss : 0.8525036573410034
# Epoch(0/1) : Batch no (538/782) : Batch loss : 0.9037678837776184
# Epoch(0/1) : Batch no (539/782) : Batch loss : 0.6475761532783508
# Epoch(0/1) : Batch no (540/782) : Batch loss : 0.6007120013237
# Epoch(0/1) : Batch no (541/782) : Batch loss : 0.7291155457496643
# Epoch(0/1) : Batch no (542/782) : Batch loss : 0.6620272994041443
# Epoch(0/1) : Batch no (543/782) : Batch loss : 0.5318546295166016
# Epoch(0/1) : Batch no (544/782) : Batch loss : 0.8617860674858093
# Epoch(0/1) : Batch no (545/782) : Batch loss : 0.7888306379318237
# Epoch(0/1) : Batch no (546/782) : Batch loss : 0.5720010995864868
# Epoch(0/1) : Batch no (547/782) : Batch loss : 0.7803098559379578
# Epoch(0/1) : Batch no (548/782) : Batch loss : 0.4727129340171814
# Epoch(0/1) : Batch no (549/782) : Batch loss : 0.5699480772018433
# Epoch(0/1) : Batch no (550/782) : Batch loss : 0.9423288702964783
# Epoch(0/1) : Batch no (551/782) : Batch loss : 0.8857942223548889
# Epoch(0/1) : Batch no (552/782) : Batch loss : 0.785001277923584
# Epoch(0/1) : Batch no (553/782) : Batch loss : 0.46853119134902954
# Epoch(0/1) : Batch no (554/782) : Batch loss : 0.568830132484436
# Epoch(0/1) : Batch no (555/782) : Batch loss : 0.6032218337059021
# Epoch(0/1) : Batch no (556/782) : Batch loss : 0.6963286995887756
# Epoch(0/1) : Batch no (557/782) : Batch loss : 0.7527478337287903
# Epoch(0/1) : Batch no (558/782) : Batch loss : 0.6693457365036011
# Epoch(0/1) : Batch no (559/782) : Batch loss : 0.8773716688156128
# Epoch(0/1) : Batch no (560/782) : Batch loss : 0.6274709105491638
# Epoch(0/1) : Batch no (561/782) : Batch loss : 0.7157411575317383
# Epoch(0/1) : Batch no (562/782) : Batch loss : 0.5040217638015747
# Epoch(0/1) : Batch no (563/782) : Batch loss : 0.6565122604370117
# Epoch(0/1) : Batch no (564/782) : Batch loss : 0.9402950406074524
# Epoch(0/1) : Batch no (565/782) : Batch loss : 0.7392297983169556
# Epoch(0/1) : Batch no (566/782) : Batch loss : 0.40652012825012207
# Epoch(0/1) : Batch no (567/782) : Batch loss : 0.8287389874458313
# Epoch(0/1) : Batch no (568/782) : Batch loss : 0.5660181045532227
# Epoch(0/1) : Batch no (569/782) : Batch loss : 0.5540725588798523
# Epoch(0/1) : Batch no (570/782) : Batch loss : 0.556664764881134
# Epoch(0/1) : Batch no (571/782) : Batch loss : 0.9034409523010254
# Epoch(0/1) : Batch no (572/782) : Batch loss : 0.4398752450942993
# Epoch(0/1) : Batch no (573/782) : Batch loss : 0.595251202583313
# Epoch(0/1) : Batch no (574/782) : Batch loss : 0.6522681713104248
# Epoch(0/1) : Batch no (575/782) : Batch loss : 0.5612399578094482
# Epoch(0/1) : Batch no (576/782) : Batch loss : 0.6093206405639648
# Epoch(0/1) : Batch no (577/782) : Batch loss : 0.834404706954956
# Epoch(0/1) : Batch no (578/782) : Batch loss : 0.7550099492073059
# Epoch(0/1) : Batch no (579/782) : Batch loss : 0.6411635875701904
# Epoch(0/1) : Batch no (580/782) : Batch loss : 0.5974940657615662
# Epoch(0/1) : Batch no (581/782) : Batch loss : 0.6641462445259094
# Epoch(0/1) : Batch no (582/782) : Batch loss : 0.6906538605690002
# Epoch(0/1) : Batch no (583/782) : Batch loss : 0.7680506706237793
# Epoch(0/1) : Batch no (584/782) : Batch loss : 0.6944881677627563
# Epoch(0/1) : Batch no (585/782) : Batch loss : 0.6632634997367859
# Epoch(0/1) : Batch no (586/782) : Batch loss : 0.3437446057796478
# Epoch(0/1) : Batch no (587/782) : Batch loss : 0.5792643427848816
# Epoch(0/1) : Batch no (588/782) : Batch loss : 0.7923182249069214
# Epoch(0/1) : Batch no (589/782) : Batch loss : 0.6722344160079956
# Epoch(0/1) : Batch no (590/782) : Batch loss : 0.7068788409233093
# Epoch(0/1) : Batch no (591/782) : Batch loss : 0.6799518465995789
# Epoch(0/1) : Batch no (592/782) : Batch loss : 0.5833005309104919
# Epoch(0/1) : Batch no (593/782) : Batch loss : 0.6410893201828003
# Epoch(0/1) : Batch no (594/782) : Batch loss : 0.6841802000999451
# Epoch(0/1) : Batch no (595/782) : Batch loss : 0.5589256286621094
# Epoch(0/1) : Batch no (596/782) : Batch loss : 0.5597396492958069
# Epoch(0/1) : Batch no (597/782) : Batch loss : 0.5971441864967346
# Epoch(0/1) : Batch no (598/782) : Batch loss : 0.4917161464691162
# Epoch(0/1) : Batch no (599/782) : Batch loss : 0.48092231154441833
# Epoch(0/1) : Batch no (600/782) : Batch loss : 0.5340909957885742
# Epoch(0/1) : Batch no (601/782) : Batch loss : 0.6833329200744629
# Epoch(0/1) : Batch no (602/782) : Batch loss : 0.4728774428367615
# Epoch(0/1) : Batch no (603/782) : Batch loss : 0.5497322678565979
# Epoch(0/1) : Batch no (604/782) : Batch loss : 0.7373598217964172
# Epoch(0/1) : Batch no (605/782) : Batch loss : 0.8552147746086121
# Epoch(0/1) : Batch no (606/782) : Batch loss : 0.8380166292190552
# Epoch(0/1) : Batch no (607/782) : Batch loss : 0.6720194816589355
# Epoch(0/1) : Batch no (608/782) : Batch loss : 0.7022720575332642
# Epoch(0/1) : Batch no (609/782) : Batch loss : 0.79046630859375
# Epoch(0/1) : Batch no (610/782) : Batch loss : 0.499022901058197
# Epoch(0/1) : Batch no (611/782) : Batch loss : 0.6425535678863525
# Epoch(0/1) : Batch no (612/782) : Batch loss : 0.8025903105735779
# Epoch(0/1) : Batch no (613/782) : Batch loss : 0.5642260909080505
# Epoch(0/1) : Batch no (614/782) : Batch loss : 0.852454662322998
# Epoch(0/1) : Batch no (615/782) : Batch loss : 0.31804168224334717
# Epoch(0/1) : Batch no (616/782) : Batch loss : 0.47968271374702454
# Epoch(0/1) : Batch no (617/782) : Batch loss : 0.6890450119972229
# Epoch(0/1) : Batch no (618/782) : Batch loss : 0.80327308177948
# Epoch(0/1) : Batch no (619/782) : Batch loss : 0.9680272340774536
# Epoch(0/1) : Batch no (620/782) : Batch loss : 0.7513344883918762
# Epoch(0/1) : Batch no (621/782) : Batch loss : 0.5810300707817078
# Epoch(0/1) : Batch no (622/782) : Batch loss : 0.7644960880279541
# Epoch(0/1) : Batch no (623/782) : Batch loss : 0.8269398808479309
# Epoch(0/1) : Batch no (624/782) : Batch loss : 0.7146465182304382
# Epoch(0/1) : Batch no (625/782) : Batch loss : 0.46416202187538147
# Epoch(0/1) : Batch no (626/782) : Batch loss : 0.6619353294372559
# Epoch(0/1) : Batch no (627/782) : Batch loss : 0.7729095220565796
# Epoch(0/1) : Batch no (628/782) : Batch loss : 0.6188546419143677
# Epoch(0/1) : Batch no (629/782) : Batch loss : 0.6108120083808899
# Epoch(0/1) : Batch no (630/782) : Batch loss : 0.7774836421012878
# Epoch(0/1) : Batch no (631/782) : Batch loss : 0.6294428110122681
# Epoch(0/1) : Batch no (632/782) : Batch loss : 0.6976101398468018
# Epoch(0/1) : Batch no (633/782) : Batch loss : 0.7310160398483276
# Epoch(0/1) : Batch no (634/782) : Batch loss : 0.5149236917495728
# Epoch(0/1) : Batch no (635/782) : Batch loss : 1.0501559972763062
# Epoch(0/1) : Batch no (636/782) : Batch loss : 0.5695151686668396
# Epoch(0/1) : Batch no (637/782) : Batch loss : 0.5968567132949829
# Epoch(0/1) : Batch no (638/782) : Batch loss : 0.7489210963249207
# Epoch(0/1) : Batch no (639/782) : Batch loss : 0.6016185879707336
# Epoch(0/1) : Batch no (640/782) : Batch loss : 0.7114300727844238
# Epoch(0/1) : Batch no (641/782) : Batch loss : 0.593833327293396
# Epoch(0/1) : Batch no (642/782) : Batch loss : 0.8856024146080017
# Epoch(0/1) : Batch no (643/782) : Batch loss : 0.4986712336540222
# Epoch(0/1) : Batch no (644/782) : Batch loss : 0.6551546454429626
# Epoch(0/1) : Batch no (645/782) : Batch loss : 0.6018632650375366
# Epoch(0/1) : Batch no (646/782) : Batch loss : 0.4844288229942322
# Epoch(0/1) : Batch no (647/782) : Batch loss : 0.8881824612617493
# Epoch(0/1) : Batch no (648/782) : Batch loss : 0.8507403135299683
# Epoch(0/1) : Batch no (649/782) : Batch loss : 0.6132176518440247
# Epoch(0/1) : Batch no (650/782) : Batch loss : 0.35042524337768555
# Epoch(0/1) : Batch no (651/782) : Batch loss : 0.48893314599990845
# Epoch(0/1) : Batch no (652/782) : Batch loss : 0.622663676738739
# Epoch(0/1) : Batch no (653/782) : Batch loss : 0.7598991394042969
# Epoch(0/1) : Batch no (654/782) : Batch loss : 0.5907592177391052
# Epoch(0/1) : Batch no (655/782) : Batch loss : 0.487245112657547
# Epoch(0/1) : Batch no (656/782) : Batch loss : 0.4272478222846985
# Epoch(0/1) : Batch no (657/782) : Batch loss : 0.6516345739364624
# Epoch(0/1) : Batch no (658/782) : Batch loss : 0.5774722695350647
# Epoch(0/1) : Batch no (659/782) : Batch loss : 0.5475752949714661
# Epoch(0/1) : Batch no (660/782) : Batch loss : 0.7843053340911865
# Epoch(0/1) : Batch no (661/782) : Batch loss : 0.5136497020721436
# Epoch(0/1) : Batch no (662/782) : Batch loss : 0.6221024990081787
# Epoch(0/1) : Batch no (663/782) : Batch loss : 0.5706425309181213
# Epoch(0/1) : Batch no (664/782) : Batch loss : 0.45540544390678406
# Epoch(0/1) : Batch no (665/782) : Batch loss : 0.6895819902420044
# Epoch(0/1) : Batch no (666/782) : Batch loss : 0.5670907497406006
# Epoch(0/1) : Batch no (667/782) : Batch loss : 0.9065672159194946
# Epoch(0/1) : Batch no (668/782) : Batch loss : 0.5965127944946289
# Epoch(0/1) : Batch no (669/782) : Batch loss : 0.8809460997581482
# Epoch(0/1) : Batch no (670/782) : Batch loss : 0.7024247646331787
# Epoch(0/1) : Batch no (671/782) : Batch loss : 0.8270292282104492
# Epoch(0/1) : Batch no (672/782) : Batch loss : 0.7160845398902893
# Epoch(0/1) : Batch no (673/782) : Batch loss : 1.0062135457992554
# Epoch(0/1) : Batch no (674/782) : Batch loss : 0.9360954165458679
# Epoch(0/1) : Batch no (675/782) : Batch loss : 0.642353355884552
# Epoch(0/1) : Batch no (676/782) : Batch loss : 0.3869257867336273
# Epoch(0/1) : Batch no (677/782) : Batch loss : 0.37298303842544556
# Epoch(0/1) : Batch no (678/782) : Batch loss : 0.4943004846572876
# Epoch(0/1) : Batch no (679/782) : Batch loss : 0.4807283282279968
# Epoch(0/1) : Batch no (680/782) : Batch loss : 0.9019479155540466
# Epoch(0/1) : Batch no (681/782) : Batch loss : 0.8776653409004211
# Epoch(0/1) : Batch no (682/782) : Batch loss : 0.5120155811309814
# Epoch(0/1) : Batch no (683/782) : Batch loss : 0.5904057025909424
# Epoch(0/1) : Batch no (684/782) : Batch loss : 0.9140757918357849
# Epoch(0/1) : Batch no (685/782) : Batch loss : 0.6051896214485168
# Epoch(0/1) : Batch no (686/782) : Batch loss : 0.6342472434043884
# Epoch(0/1) : Batch no (687/782) : Batch loss : 0.6031427979469299
# Epoch(0/1) : Batch no (688/782) : Batch loss : 0.5730608105659485
# Epoch(0/1) : Batch no (689/782) : Batch loss : 0.7099473476409912
# Epoch(0/1) : Batch no (690/782) : Batch loss : 0.5924047827720642
# Epoch(0/1) : Batch no (691/782) : Batch loss : 0.566074550151825
# Epoch(0/1) : Batch no (692/782) : Batch loss : 0.8521831035614014
# Epoch(0/1) : Batch no (693/782) : Batch loss : 0.6087217926979065
# Epoch(0/1) : Batch no (694/782) : Batch loss : 0.9281225204467773
# Epoch(0/1) : Batch no (695/782) : Batch loss : 0.5720177888870239
# Epoch(0/1) : Batch no (696/782) : Batch loss : 0.8650475740432739
# Epoch(0/1) : Batch no (697/782) : Batch loss : 0.5760868191719055
# Epoch(0/1) : Batch no (698/782) : Batch loss : 0.5816888809204102
# Epoch(0/1) : Batch no (699/782) : Batch loss : 0.5299564003944397
# Epoch(0/1) : Batch no (700/782) : Batch loss : 0.5164209008216858
# Epoch(0/1) : Batch no (701/782) : Batch loss : 0.37849459052085876
# Epoch(0/1) : Batch no (702/782) : Batch loss : 0.5564286112785339
# Epoch(0/1) : Batch no (703/782) : Batch loss : 0.6918730139732361
# Epoch(0/1) : Batch no (704/782) : Batch loss : 1.0069029331207275
# Epoch(0/1) : Batch no (705/782) : Batch loss : 0.8510339260101318
# Epoch(0/1) : Batch no (706/782) : Batch loss : 0.567000687122345
# Epoch(0/1) : Batch no (707/782) : Batch loss : 0.5427166819572449
# Epoch(0/1) : Batch no (708/782) : Batch loss : 0.8286911249160767
# Epoch(0/1) : Batch no (709/782) : Batch loss : 0.8281471729278564
# Epoch(0/1) : Batch no (710/782) : Batch loss : 0.7907833456993103
# Epoch(0/1) : Batch no (711/782) : Batch loss : 0.6280519962310791
# Epoch(0/1) : Batch no (712/782) : Batch loss : 0.6243137121200562
# Epoch(0/1) : Batch no (713/782) : Batch loss : 0.6703833341598511
# Epoch(0/1) : Batch no (714/782) : Batch loss : 0.6308926939964294
# Epoch(0/1) : Batch no (715/782) : Batch loss : 0.5727002620697021
# Epoch(0/1) : Batch no (716/782) : Batch loss : 0.679763674736023
# Epoch(0/1) : Batch no (717/782) : Batch loss : 0.6591094136238098
# Epoch(0/1) : Batch no (718/782) : Batch loss : 0.7459741234779358
# Epoch(0/1) : Batch no (719/782) : Batch loss : 0.6356518864631653
# Epoch(0/1) : Batch no (720/782) : Batch loss : 0.5092251896858215
# Epoch(0/1) : Batch no (721/782) : Batch loss : 0.5396003723144531
# Epoch(0/1) : Batch no (722/782) : Batch loss : 0.6415433883666992
# Epoch(0/1) : Batch no (723/782) : Batch loss : 0.7088257670402527
# Epoch(0/1) : Batch no (724/782) : Batch loss : 0.5030434131622314
# Epoch(0/1) : Batch no (725/782) : Batch loss : 0.7944873571395874
# Epoch(0/1) : Batch no (726/782) : Batch loss : 0.6954920887947083
# Epoch(0/1) : Batch no (727/782) : Batch loss : 0.8005495667457581
# Epoch(0/1) : Batch no (728/782) : Batch loss : 0.730128824710846
# Epoch(0/1) : Batch no (729/782) : Batch loss : 0.6224459409713745
# Epoch(0/1) : Batch no (730/782) : Batch loss : 0.4909372925758362
# Epoch(0/1) : Batch no (731/782) : Batch loss : 0.6218165159225464
# Epoch(0/1) : Batch no (732/782) : Batch loss : 0.7528107762336731
# Epoch(0/1) : Batch no (733/782) : Batch loss : 0.7370554208755493
# Epoch(0/1) : Batch no (734/782) : Batch loss : 0.6103340983390808
# Epoch(0/1) : Batch no (735/782) : Batch loss : 0.6738354563713074
# Epoch(0/1) : Batch no (736/782) : Batch loss : 0.7725987434387207
# Epoch(0/1) : Batch no (737/782) : Batch loss : 0.4346466660499573
# Epoch(0/1) : Batch no (738/782) : Batch loss : 0.7139679193496704
# Epoch(0/1) : Batch no (739/782) : Batch loss : 0.7490798830986023
# Epoch(0/1) : Batch no (740/782) : Batch loss : 0.6538193821907043
# Epoch(0/1) : Batch no (741/782) : Batch loss : 0.4846333861351013
# Epoch(0/1) : Batch no (742/782) : Batch loss : 0.5505260229110718
# Epoch(0/1) : Batch no (743/782) : Batch loss : 0.9902997612953186
# Epoch(0/1) : Batch no (744/782) : Batch loss : 0.5529357194900513
# Epoch(0/1) : Batch no (745/782) : Batch loss : 0.6258949637413025
# Epoch(0/1) : Batch no (746/782) : Batch loss : 0.6086411476135254
# Epoch(0/1) : Batch no (747/782) : Batch loss : 0.6729491949081421
# Epoch(0/1) : Batch no (748/782) : Batch loss : 0.7134758830070496
# Epoch(0/1) : Batch no (749/782) : Batch loss : 0.6416707038879395
# Epoch(0/1) : Batch no (750/782) : Batch loss : 0.649284839630127
# Epoch(0/1) : Batch no (751/782) : Batch loss : 0.6104798316955566
# Epoch(0/1) : Batch no (752/782) : Batch loss : 0.9363102912902832
# Epoch(0/1) : Batch no (753/782) : Batch loss : 0.492337167263031
# Epoch(0/1) : Batch no (754/782) : Batch loss : 0.543627917766571
# Epoch(0/1) : Batch no (755/782) : Batch loss : 0.4392910301685333
# Epoch(0/1) : Batch no (756/782) : Batch loss : 0.608822226524353
# Epoch(0/1) : Batch no (757/782) : Batch loss : 0.7390196919441223
# Epoch(0/1) : Batch no (758/782) : Batch loss : 0.44332024455070496
# Epoch(0/1) : Batch no (759/782) : Batch loss : 0.704151451587677
# Epoch(0/1) : Batch no (760/782) : Batch loss : 0.7200150489807129
# Epoch(0/1) : Batch no (761/782) : Batch loss : 0.4443050026893616
# Epoch(0/1) : Batch no (762/782) : Batch loss : 0.7956926226615906
# Epoch(0/1) : Batch no (763/782) : Batch loss : 0.6788642406463623
# Epoch(0/1) : Batch no (764/782) : Batch loss : 0.7136522531509399
# Epoch(0/1) : Batch no (765/782) : Batch loss : 0.5223180055618286
# Epoch(0/1) : Batch no (766/782) : Batch loss : 0.6236667633056641
# Epoch(0/1) : Batch no (767/782) : Batch loss : 0.6478024125099182
# Epoch(0/1) : Batch no (768/782) : Batch loss : 0.5925496816635132
# Epoch(0/1) : Batch no (769/782) : Batch loss : 0.5621069669723511
# Epoch(0/1) : Batch no (770/782) : Batch loss : 0.7060555219650269
# Epoch(0/1) : Batch no (771/782) : Batch loss : 0.8352022171020508
# Epoch(0/1) : Batch no (772/782) : Batch loss : 0.3232179880142212
# Epoch(0/1) : Batch no (773/782) : Batch loss : 0.6897187232971191
# Epoch(0/1) : Batch no (774/782) : Batch loss : 0.6210914254188538
# Epoch(0/1) : Batch no (775/782) : Batch loss : 0.9435157775878906
# Epoch(0/1) : Batch no (776/782) : Batch loss : 0.7404466867446899
# Epoch(0/1) : Batch no (777/782) : Batch loss : 0.6873690485954285
# Epoch(0/1) : Batch no (778/782) : Batch loss : 0.7375560998916626
# Epoch(0/1) : Batch no (779/782) : Batch loss : 0.4216282367706299
# Epoch(0/1) : Batch no (780/782) : Batch loss : 0.5208527445793152
# Epoch(0/1) : Batch no (781/782) : Batch loss : 0.5948029160499573
# Epoch(0/1) : Batch no (782/782) : Batch loss : 0.9290857911109924
# Training loss : 0.7118572208963697

# %% [markdown]
# ### Get Accuracy

# %%
model.to('cpu')

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0

    #set_trace()
    for batch_n, (X_test, y_test) in enumerate(test_loader,1):

        y_pred = model(X_test)
        sfmax = torch.exp(y_pred)

        y_pred_class = torch.argmax(sfmax, 1)
        total += y_test.size(0)
        num_correct += (y_pred_class == y_test).sum().item()
        print(f'Batch ({batch_n}/{len(test_loader)})')

        if batch_n == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 80.0%

# %% [markdown]
# ### Fine-tuning on the Last CNN block

# %%
model.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU(inplace=True)
#   (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU(inplace=True)
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU(inplace=True)
#   (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): ReLU(inplace=True)
#   (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (13): ReLU(inplace=True)
#   (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): ReLU(inplace=True)
#   (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): ReLU(inplace=True)
#   (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (20): ReLU(inplace=True)
#   (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): ReLU(inplace=True)
#   (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (27): ReLU(inplace=True)
#   (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (29): ReLU(inplace=True)
#   (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
# the last Conv block ranges from 24 to 31, make these trainable
for i in range(24,31):
  model.features[i].requires_grad = True

model = model.to(device)
optimizer = Adam(filter(lambda p: p.requires_grad, model.parameters()))

# %%
epochs = 3
batch_loss = 0
cum_epoch_loss = 0

for i in range(epochs):
  cum_epoch_loss = 0

  for batch_n, (X_train, y_train) in enumerate(train_loader,1):
    X_train = X_train.to(device)
    y_train = y_train.to(device)

    optimizer.zero_grad()
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)
    loss.backward()
    optimizer.step()

    batch_loss += loss.item()
    print(f'Epoch({i+1}/{epochs}) : Batch no: ({batch_n}/{len(train_loader)}) : Batch loss : {loss.item()}')

  print(f'Training loss : {batch_loss/len(train_loader)}')
# Out:
# Epoch(1/3) : Batch no: (1/782) : Batch loss : 0.3980860114097595
# Epoch(1/3) : Batch no: (2/782) : Batch loss : 0.448984831571579
# Epoch(1/3) : Batch no: (3/782) : Batch loss : 0.5425161719322205
# Epoch(1/3) : Batch no: (4/782) : Batch loss : 0.5636059641838074
# Epoch(1/3) : Batch no: (5/782) : Batch loss : 0.48988616466522217
# Epoch(1/3) : Batch no: (6/782) : Batch loss : 0.7176986336708069
# Epoch(1/3) : Batch no: (7/782) : Batch loss : 0.7442265748977661
# Epoch(1/3) : Batch no: (8/782) : Batch loss : 0.5768059492111206
# Epoch(1/3) : Batch no: (9/782) : Batch loss : 0.5499346852302551
# Epoch(1/3) : Batch no: (10/782) : Batch loss : 0.3052346706390381
# Epoch(1/3) : Batch no: (11/782) : Batch loss : 0.6364123225212097
# Epoch(1/3) : Batch no: (12/782) : Batch loss : 0.538742184638977
# Epoch(1/3) : Batch no: (13/782) : Batch loss : 0.44893333315849304
# Epoch(1/3) : Batch no: (14/782) : Batch loss : 0.5587729811668396
# Epoch(1/3) : Batch no: (15/782) : Batch loss : 0.49918895959854126
# Epoch(1/3) : Batch no: (16/782) : Batch loss : 0.6127226948738098
# Epoch(1/3) : Batch no: (17/782) : Batch loss : 0.7126162648200989
# Epoch(1/3) : Batch no: (18/782) : Batch loss : 0.4732675850391388
# Epoch(1/3) : Batch no: (19/782) : Batch loss : 0.4803839921951294
# Epoch(1/3) : Batch no: (20/782) : Batch loss : 0.43660786747932434
# Epoch(1/3) : Batch no: (21/782) : Batch loss : 0.45320188999176025
# Epoch(1/3) : Batch no: (22/782) : Batch loss : 0.3314286470413208
# Epoch(1/3) : Batch no: (23/782) : Batch loss : 0.5365602374076843
# Epoch(1/3) : Batch no: (24/782) : Batch loss : 0.4458991587162018
# Epoch(1/3) : Batch no: (25/782) : Batch loss : 0.39902281761169434
# Epoch(1/3) : Batch no: (26/782) : Batch loss : 0.3754400610923767
# Epoch(1/3) : Batch no: (27/782) : Batch loss : 0.7108736038208008
# Epoch(1/3) : Batch no: (28/782) : Batch loss : 0.4666081666946411
# Epoch(1/3) : Batch no: (29/782) : Batch loss : 0.49511390924453735
# Epoch(1/3) : Batch no: (30/782) : Batch loss : 0.5489017963409424
# Epoch(1/3) : Batch no: (31/782) : Batch loss : 0.4693194031715393
# Epoch(1/3) : Batch no: (32/782) : Batch loss : 0.5092253088951111
# Epoch(1/3) : Batch no: (33/782) : Batch loss : 0.5472761988639832
# Epoch(1/3) : Batch no: (34/782) : Batch loss : 0.49119311571121216
# Epoch(1/3) : Batch no: (35/782) : Batch loss : 0.564517617225647
# Epoch(1/3) : Batch no: (36/782) : Batch loss : 0.5404647588729858
# Epoch(1/3) : Batch no: (37/782) : Batch loss : 0.5469914078712463
# Epoch(1/3) : Batch no: (38/782) : Batch loss : 0.4528811573982239
# Epoch(1/3) : Batch no: (39/782) : Batch loss : 0.5183466076850891
# Epoch(1/3) : Batch no: (40/782) : Batch loss : 0.6129206418991089
# Epoch(1/3) : Batch no: (41/782) : Batch loss : 0.2961437404155731
# Epoch(1/3) : Batch no: (42/782) : Batch loss : 0.35186105966567993
# Epoch(1/3) : Batch no: (43/782) : Batch loss : 0.5998765230178833
# Epoch(1/3) : Batch no: (44/782) : Batch loss : 0.4007042646408081
# Epoch(1/3) : Batch no: (45/782) : Batch loss : 0.737612783908844
# Epoch(1/3) : Batch no: (46/782) : Batch loss : 0.42441052198410034
# Epoch(1/3) : Batch no: (47/782) : Batch loss : 0.38329222798347473
# Epoch(1/3) : Batch no: (48/782) : Batch loss : 0.4973747134208679
# Epoch(1/3) : Batch no: (49/782) : Batch loss : 0.36767807602882385
# Epoch(1/3) : Batch no: (50/782) : Batch loss : 0.3497150242328644
# Epoch(1/3) : Batch no: (51/782) : Batch loss : 0.4315412640571594
# Epoch(1/3) : Batch no: (52/782) : Batch loss : 0.34440183639526367
# Epoch(1/3) : Batch no: (53/782) : Batch loss : 0.6844090223312378
# Epoch(1/3) : Batch no: (54/782) : Batch loss : 0.30044323205947876
# Epoch(1/3) : Batch no: (55/782) : Batch loss : 0.29171618819236755
# Epoch(1/3) : Batch no: (56/782) : Batch loss : 0.6172863841056824
# Epoch(1/3) : Batch no: (57/782) : Batch loss : 0.46121135354042053
# Epoch(1/3) : Batch no: (58/782) : Batch loss : 0.5627139806747437
# Epoch(1/3) : Batch no: (59/782) : Batch loss : 0.6521016955375671
# Epoch(1/3) : Batch no: (60/782) : Batch loss : 0.3133672773838043
# Epoch(1/3) : Batch no: (61/782) : Batch loss : 0.622468113899231
# Epoch(1/3) : Batch no: (62/782) : Batch loss : 0.5096355676651001
# Epoch(1/3) : Batch no: (63/782) : Batch loss : 0.2741784155368805
# Epoch(1/3) : Batch no: (64/782) : Batch loss : 0.5521286725997925
# Epoch(1/3) : Batch no: (65/782) : Batch loss : 0.4023900032043457
# Epoch(1/3) : Batch no: (66/782) : Batch loss : 0.5079810619354248
# Epoch(1/3) : Batch no: (67/782) : Batch loss : 0.28277716040611267
# Epoch(1/3) : Batch no: (68/782) : Batch loss : 0.3889161944389343
# Epoch(1/3) : Batch no: (69/782) : Batch loss : 0.4137527346611023
# Epoch(1/3) : Batch no: (70/782) : Batch loss : 0.46824339032173157
# Epoch(1/3) : Batch no: (71/782) : Batch loss : 0.5722106099128723
# Epoch(1/3) : Batch no: (72/782) : Batch loss : 0.3873657286167145
# Epoch(1/3) : Batch no: (73/782) : Batch loss : 0.43128249049186707
# Epoch(1/3) : Batch no: (74/782) : Batch loss : 0.3332773745059967
# Epoch(1/3) : Batch no: (75/782) : Batch loss : 0.5757185816764832
# Epoch(1/3) : Batch no: (76/782) : Batch loss : 0.6250282526016235
# Epoch(1/3) : Batch no: (77/782) : Batch loss : 0.4650435149669647
# Epoch(1/3) : Batch no: (78/782) : Batch loss : 0.3694077432155609
# Epoch(1/3) : Batch no: (79/782) : Batch loss : 0.6221299171447754
# Epoch(1/3) : Batch no: (80/782) : Batch loss : 0.7502993941307068
# Epoch(1/3) : Batch no: (81/782) : Batch loss : 0.6321088671684265
# Epoch(1/3) : Batch no: (82/782) : Batch loss : 0.8187225461006165
# Epoch(1/3) : Batch no: (83/782) : Batch loss : 0.44821906089782715
# Epoch(1/3) : Batch no: (84/782) : Batch loss : 0.3051532804965973
# Epoch(1/3) : Batch no: (85/782) : Batch loss : 0.8844918012619019
# Epoch(1/3) : Batch no: (86/782) : Batch loss : 0.3878251612186432
# Epoch(1/3) : Batch no: (87/782) : Batch loss : 0.5462074279785156
# Epoch(1/3) : Batch no: (88/782) : Batch loss : 0.7550942301750183
# Epoch(1/3) : Batch no: (89/782) : Batch loss : 0.39808034896850586
# Epoch(1/3) : Batch no: (90/782) : Batch loss : 0.39524543285369873
# Epoch(1/3) : Batch no: (91/782) : Batch loss : 0.5155328512191772
# Epoch(1/3) : Batch no: (92/782) : Batch loss : 0.29192930459976196
# Epoch(1/3) : Batch no: (93/782) : Batch loss : 0.30925285816192627
# Epoch(1/3) : Batch no: (94/782) : Batch loss : 0.37372058629989624
# Epoch(1/3) : Batch no: (95/782) : Batch loss : 0.7995827198028564
# Epoch(1/3) : Batch no: (96/782) : Batch loss : 0.535656750202179
# Epoch(1/3) : Batch no: (97/782) : Batch loss : 0.6817585825920105
# Epoch(1/3) : Batch no: (98/782) : Batch loss : 0.41461336612701416
# Epoch(1/3) : Batch no: (99/782) : Batch loss : 0.5476475358009338
# Epoch(1/3) : Batch no: (100/782) : Batch loss : 0.5728393197059631
# Epoch(1/3) : Batch no: (101/782) : Batch loss : 0.4630661904811859
# Epoch(1/3) : Batch no: (102/782) : Batch loss : 0.47701290249824524
# Epoch(1/3) : Batch no: (103/782) : Batch loss : 0.37942731380462646
# Epoch(1/3) : Batch no: (104/782) : Batch loss : 0.4717296063899994
# Epoch(1/3) : Batch no: (105/782) : Batch loss : 0.41547784209251404
# Epoch(1/3) : Batch no: (106/782) : Batch loss : 0.37534675002098083
# Epoch(1/3) : Batch no: (107/782) : Batch loss : 0.18901920318603516
# Epoch(1/3) : Batch no: (108/782) : Batch loss : 0.39558228850364685
# Epoch(1/3) : Batch no: (109/782) : Batch loss : 0.4508909583091736
# Epoch(1/3) : Batch no: (110/782) : Batch loss : 0.6276592016220093
# Epoch(1/3) : Batch no: (111/782) : Batch loss : 0.4609993100166321
# Epoch(1/3) : Batch no: (112/782) : Batch loss : 0.38730186223983765
# Epoch(1/3) : Batch no: (113/782) : Batch loss : 0.6398550271987915
# Epoch(1/3) : Batch no: (114/782) : Batch loss : 0.714745044708252
# Epoch(1/3) : Batch no: (115/782) : Batch loss : 0.24848152697086334
# Epoch(1/3) : Batch no: (116/782) : Batch loss : 0.32376980781555176
# Epoch(1/3) : Batch no: (117/782) : Batch loss : 0.3228271007537842
# Epoch(1/3) : Batch no: (118/782) : Batch loss : 0.5110111236572266
# Epoch(1/3) : Batch no: (119/782) : Batch loss : 0.5120230317115784
# Epoch(1/3) : Batch no: (120/782) : Batch loss : 0.48837608098983765
# Epoch(1/3) : Batch no: (121/782) : Batch loss : 0.46715980768203735
# Epoch(1/3) : Batch no: (122/782) : Batch loss : 0.4660024046897888
# Epoch(1/3) : Batch no: (123/782) : Batch loss : 0.3358069360256195
# Epoch(1/3) : Batch no: (124/782) : Batch loss : 0.34290093183517456
# Epoch(1/3) : Batch no: (125/782) : Batch loss : 0.5099800229072571
# Epoch(1/3) : Batch no: (126/782) : Batch loss : 0.38024061918258667
# Epoch(1/3) : Batch no: (127/782) : Batch loss : 0.4425181448459625
# Epoch(1/3) : Batch no: (128/782) : Batch loss : 0.5282045602798462
# Epoch(1/3) : Batch no: (129/782) : Batch loss : 0.22721269726753235
# Epoch(1/3) : Batch no: (130/782) : Batch loss : 0.3889614939689636
# Epoch(1/3) : Batch no: (131/782) : Batch loss : 0.666562020778656
# Epoch(1/3) : Batch no: (132/782) : Batch loss : 0.585277795791626
# Epoch(1/3) : Batch no: (133/782) : Batch loss : 0.34356164932250977
# Epoch(1/3) : Batch no: (134/782) : Batch loss : 0.6122123599052429
# Epoch(1/3) : Batch no: (135/782) : Batch loss : 0.3660971522331238
# Epoch(1/3) : Batch no: (136/782) : Batch loss : 0.3091578185558319
# Epoch(1/3) : Batch no: (137/782) : Batch loss : 0.4985957145690918
# Epoch(1/3) : Batch no: (138/782) : Batch loss : 0.47835633158683777
# Epoch(1/3) : Batch no: (139/782) : Batch loss : 0.4175724983215332
# Epoch(1/3) : Batch no: (140/782) : Batch loss : 0.42227402329444885
# Epoch(1/3) : Batch no: (141/782) : Batch loss : 0.4148949682712555
# Epoch(1/3) : Batch no: (142/782) : Batch loss : 0.5654333829879761
# Epoch(1/3) : Batch no: (143/782) : Batch loss : 0.3337132930755615
# Epoch(1/3) : Batch no: (144/782) : Batch loss : 0.5132083296775818
# Epoch(1/3) : Batch no: (145/782) : Batch loss : 0.4408673942089081
# Epoch(1/3) : Batch no: (146/782) : Batch loss : 0.46639981865882874
# Epoch(1/3) : Batch no: (147/782) : Batch loss : 0.4771192669868469
# Epoch(1/3) : Batch no: (148/782) : Batch loss : 0.45311349630355835
# Epoch(1/3) : Batch no: (149/782) : Batch loss : 0.6520311236381531
# Epoch(1/3) : Batch no: (150/782) : Batch loss : 0.3221825361251831
# Epoch(1/3) : Batch no: (151/782) : Batch loss : 0.45716652274131775
# Epoch(1/3) : Batch no: (152/782) : Batch loss : 0.6543129682540894
# Epoch(1/3) : Batch no: (153/782) : Batch loss : 0.5684207677841187
# Epoch(1/3) : Batch no: (154/782) : Batch loss : 0.31363704800605774
# Epoch(1/3) : Batch no: (155/782) : Batch loss : 0.4152437150478363
# Epoch(1/3) : Batch no: (156/782) : Batch loss : 0.5141487717628479
# Epoch(1/3) : Batch no: (157/782) : Batch loss : 0.3842374384403229
# Epoch(1/3) : Batch no: (158/782) : Batch loss : 0.5574270486831665
# Epoch(1/3) : Batch no: (159/782) : Batch loss : 0.3878346085548401
# Epoch(1/3) : Batch no: (160/782) : Batch loss : 0.6289242506027222
# Epoch(1/3) : Batch no: (161/782) : Batch loss : 0.39025744795799255
# Epoch(1/3) : Batch no: (162/782) : Batch loss : 0.3577970862388611
# Epoch(1/3) : Batch no: (163/782) : Batch loss : 0.5637878775596619
# Epoch(1/3) : Batch no: (164/782) : Batch loss : 0.28686684370040894
# Epoch(1/3) : Batch no: (165/782) : Batch loss : 0.46455472707748413
# Epoch(1/3) : Batch no: (166/782) : Batch loss : 0.4578794836997986
# Epoch(1/3) : Batch no: (167/782) : Batch loss : 0.5313665270805359
# Epoch(1/3) : Batch no: (168/782) : Batch loss : 0.5229265093803406
# Epoch(1/3) : Batch no: (169/782) : Batch loss : 0.6275468468666077
# Epoch(1/3) : Batch no: (170/782) : Batch loss : 0.48491644859313965
# Epoch(1/3) : Batch no: (171/782) : Batch loss : 0.4221327304840088
# Epoch(1/3) : Batch no: (172/782) : Batch loss : 0.4021376073360443
# Epoch(1/3) : Batch no: (173/782) : Batch loss : 0.37900254130363464
# Epoch(1/3) : Batch no: (174/782) : Batch loss : 0.5044623613357544
# Epoch(1/3) : Batch no: (175/782) : Batch loss : 0.33795595169067383
# Epoch(1/3) : Batch no: (176/782) : Batch loss : 0.8277083039283752
# Epoch(1/3) : Batch no: (177/782) : Batch loss : 0.5157742500305176
# Epoch(1/3) : Batch no: (178/782) : Batch loss : 0.5157608985900879
# Epoch(1/3) : Batch no: (179/782) : Batch loss : 0.345982164144516
# Epoch(1/3) : Batch no: (180/782) : Batch loss : 0.6366668939590454
# Epoch(1/3) : Batch no: (181/782) : Batch loss : 0.35918986797332764
# Epoch(1/3) : Batch no: (182/782) : Batch loss : 0.551104724407196
# Epoch(1/3) : Batch no: (183/782) : Batch loss : 0.607210099697113
# Epoch(1/3) : Batch no: (184/782) : Batch loss : 0.2686067819595337
# Epoch(1/3) : Batch no: (185/782) : Batch loss : 0.5967872142791748
# Epoch(1/3) : Batch no: (186/782) : Batch loss : 0.5813232064247131
# Epoch(1/3) : Batch no: (187/782) : Batch loss : 0.4634109437465668
# Epoch(1/3) : Batch no: (188/782) : Batch loss : 0.6387868523597717
# Epoch(1/3) : Batch no: (189/782) : Batch loss : 0.36792752146720886
# Epoch(1/3) : Batch no: (190/782) : Batch loss : 0.5055273771286011
# Epoch(1/3) : Batch no: (191/782) : Batch loss : 0.5738909840583801
# Epoch(1/3) : Batch no: (192/782) : Batch loss : 0.2960674464702606
# Epoch(1/3) : Batch no: (193/782) : Batch loss : 0.3410537540912628
# Epoch(1/3) : Batch no: (194/782) : Batch loss : 0.48667922616004944
# Epoch(1/3) : Batch no: (195/782) : Batch loss : 0.43099090456962585
# Epoch(1/3) : Batch no: (196/782) : Batch loss : 0.5573363900184631
# Epoch(1/3) : Batch no: (197/782) : Batch loss : 0.40135228633880615
# Epoch(1/3) : Batch no: (198/782) : Batch loss : 0.4636746346950531
# Epoch(1/3) : Batch no: (199/782) : Batch loss : 0.39468541741371155
# Epoch(1/3) : Batch no: (200/782) : Batch loss : 0.4818512201309204
# Epoch(1/3) : Batch no: (201/782) : Batch loss : 0.34506312012672424
# Epoch(1/3) : Batch no: (202/782) : Batch loss : 0.458181232213974
# Epoch(1/3) : Batch no: (203/782) : Batch loss : 0.6091341972351074
# Epoch(1/3) : Batch no: (204/782) : Batch loss : 0.4249519109725952
# Epoch(1/3) : Batch no: (205/782) : Batch loss : 0.4961775839328766
# Epoch(1/3) : Batch no: (206/782) : Batch loss : 0.4609195291996002
# Epoch(1/3) : Batch no: (207/782) : Batch loss : 0.7066506147384644
# Epoch(1/3) : Batch no: (208/782) : Batch loss : 0.48201048374176025
# Epoch(1/3) : Batch no: (209/782) : Batch loss : 0.32237333059310913
# Epoch(1/3) : Batch no: (210/782) : Batch loss : 0.30378979444503784
# Epoch(1/3) : Batch no: (211/782) : Batch loss : 0.6351953744888306
# Epoch(1/3) : Batch no: (212/782) : Batch loss : 0.3300313651561737
# Epoch(1/3) : Batch no: (213/782) : Batch loss : 0.5900116562843323
# Epoch(1/3) : Batch no: (214/782) : Batch loss : 0.4060782194137573
# Epoch(1/3) : Batch no: (215/782) : Batch loss : 0.4402453899383545
# Epoch(1/3) : Batch no: (216/782) : Batch loss : 0.4532250165939331
# Epoch(1/3) : Batch no: (217/782) : Batch loss : 0.40061190724372864
# Epoch(1/3) : Batch no: (218/782) : Batch loss : 0.3878394663333893
# Epoch(1/3) : Batch no: (219/782) : Batch loss : 0.6127452850341797
# Epoch(1/3) : Batch no: (220/782) : Batch loss : 0.4368816912174225
# Epoch(1/3) : Batch no: (221/782) : Batch loss : 0.5901899933815002
# Epoch(1/3) : Batch no: (222/782) : Batch loss : 0.3446389436721802
# Epoch(1/3) : Batch no: (223/782) : Batch loss : 0.5531455874443054
# Epoch(1/3) : Batch no: (224/782) : Batch loss : 0.4894903600215912
# Epoch(1/3) : Batch no: (225/782) : Batch loss : 0.4065954089164734
# Epoch(1/3) : Batch no: (226/782) : Batch loss : 0.41610896587371826
# Epoch(1/3) : Batch no: (227/782) : Batch loss : 0.4287525713443756
# Epoch(1/3) : Batch no: (228/782) : Batch loss : 0.6089858412742615
# Epoch(1/3) : Batch no: (229/782) : Batch loss : 0.3311678469181061
# Epoch(1/3) : Batch no: (230/782) : Batch loss : 0.5644440650939941
# Epoch(1/3) : Batch no: (231/782) : Batch loss : 0.3640344440937042
# Epoch(1/3) : Batch no: (232/782) : Batch loss : 0.3212285041809082
# Epoch(1/3) : Batch no: (233/782) : Batch loss : 0.2668807804584503
# Epoch(1/3) : Batch no: (234/782) : Batch loss : 0.3517937660217285
# Epoch(1/3) : Batch no: (235/782) : Batch loss : 0.6496870517730713
# Epoch(1/3) : Batch no: (236/782) : Batch loss : 0.5186525583267212
# Epoch(1/3) : Batch no: (237/782) : Batch loss : 0.38551363348960876
# Epoch(1/3) : Batch no: (238/782) : Batch loss : 0.4418528378009796
# Epoch(1/3) : Batch no: (239/782) : Batch loss : 0.7595402002334595
# Epoch(1/3) : Batch no: (240/782) : Batch loss : 0.43446609377861023
# Epoch(1/3) : Batch no: (241/782) : Batch loss : 0.7099131345748901
# Epoch(1/3) : Batch no: (242/782) : Batch loss : 0.38998642563819885
# Epoch(1/3) : Batch no: (243/782) : Batch loss : 0.48213309049606323
# Epoch(1/3) : Batch no: (244/782) : Batch loss : 0.5057021975517273
# Epoch(1/3) : Batch no: (245/782) : Batch loss : 0.5607670545578003
# Epoch(1/3) : Batch no: (246/782) : Batch loss : 0.40313756465911865
# Epoch(1/3) : Batch no: (247/782) : Batch loss : 0.5042080879211426
# Epoch(1/3) : Batch no: (248/782) : Batch loss : 0.42716410756111145
# Epoch(1/3) : Batch no: (249/782) : Batch loss : 0.47131428122520447
# Epoch(1/3) : Batch no: (250/782) : Batch loss : 0.3887934982776642
# Epoch(1/3) : Batch no: (251/782) : Batch loss : 0.3702770173549652
# Epoch(1/3) : Batch no: (252/782) : Batch loss : 0.4687685966491699
# Epoch(1/3) : Batch no: (253/782) : Batch loss : 0.3446543514728546
# Epoch(1/3) : Batch no: (254/782) : Batch loss : 0.37131375074386597
# Epoch(1/3) : Batch no: (255/782) : Batch loss : 0.5050240159034729
# Epoch(1/3) : Batch no: (256/782) : Batch loss : 0.39166390895843506
# Epoch(1/3) : Batch no: (257/782) : Batch loss : 0.7243741154670715
# Epoch(1/3) : Batch no: (258/782) : Batch loss : 0.32148319482803345
# Epoch(1/3) : Batch no: (259/782) : Batch loss : 0.36632490158081055
# Epoch(1/3) : Batch no: (260/782) : Batch loss : 0.3406810760498047
# Epoch(1/3) : Batch no: (261/782) : Batch loss : 0.35162895917892456
# Epoch(1/3) : Batch no: (262/782) : Batch loss : 0.2971973717212677
# Epoch(1/3) : Batch no: (263/782) : Batch loss : 0.40370702743530273
# Epoch(1/3) : Batch no: (264/782) : Batch loss : 0.3852766156196594
# Epoch(1/3) : Batch no: (265/782) : Batch loss : 0.43468213081359863
# Epoch(1/3) : Batch no: (266/782) : Batch loss : 0.3368512988090515
# Epoch(1/3) : Batch no: (267/782) : Batch loss : 0.4856237769126892
# Epoch(1/3) : Batch no: (268/782) : Batch loss : 0.5144882202148438
# Epoch(1/3) : Batch no: (269/782) : Batch loss : 0.3808176815509796
# Epoch(1/3) : Batch no: (270/782) : Batch loss : 0.7633980512619019
# Epoch(1/3) : Batch no: (271/782) : Batch loss : 0.4102916121482849
# Epoch(1/3) : Batch no: (272/782) : Batch loss : 0.6685123443603516
# Epoch(1/3) : Batch no: (273/782) : Batch loss : 0.36239027976989746
# Epoch(1/3) : Batch no: (274/782) : Batch loss : 0.38649311661720276
# Epoch(1/3) : Batch no: (275/782) : Batch loss : 0.5972237586975098
# Epoch(1/3) : Batch no: (276/782) : Batch loss : 0.373605340719223
# Epoch(1/3) : Batch no: (277/782) : Batch loss : 0.4434913694858551
# Epoch(1/3) : Batch no: (278/782) : Batch loss : 0.35879451036453247
# Epoch(1/3) : Batch no: (279/782) : Batch loss : 0.4181802272796631
# Epoch(1/3) : Batch no: (280/782) : Batch loss : 0.6170557141304016
# Epoch(1/3) : Batch no: (281/782) : Batch loss : 0.5775063037872314
# Epoch(1/3) : Batch no: (282/782) : Batch loss : 0.5328925848007202
# Epoch(1/3) : Batch no: (283/782) : Batch loss : 0.5155717134475708
# Epoch(1/3) : Batch no: (284/782) : Batch loss : 0.47956156730651855
# Epoch(1/3) : Batch no: (285/782) : Batch loss : 0.5121825337409973
# Epoch(1/3) : Batch no: (286/782) : Batch loss : 0.5303443670272827
# Epoch(1/3) : Batch no: (287/782) : Batch loss : 0.6719594597816467
# Epoch(1/3) : Batch no: (288/782) : Batch loss : 0.5320688486099243
# Epoch(1/3) : Batch no: (289/782) : Batch loss : 0.4360823631286621
# Epoch(1/3) : Batch no: (290/782) : Batch loss : 0.45796817541122437
# Epoch(1/3) : Batch no: (291/782) : Batch loss : 0.7954369783401489
# Epoch(1/3) : Batch no: (292/782) : Batch loss : 0.503602921962738
# Epoch(1/3) : Batch no: (293/782) : Batch loss : 0.6215866804122925
# Epoch(1/3) : Batch no: (294/782) : Batch loss : 0.6664195656776428
# Epoch(1/3) : Batch no: (295/782) : Batch loss : 0.44208452105522156
# Epoch(1/3) : Batch no: (296/782) : Batch loss : 0.5799782276153564
# Epoch(1/3) : Batch no: (297/782) : Batch loss : 0.5037266612052917
# Epoch(1/3) : Batch no: (298/782) : Batch loss : 0.4859201908111572
# Epoch(1/3) : Batch no: (299/782) : Batch loss : 0.6821980476379395
# Epoch(1/3) : Batch no: (300/782) : Batch loss : 0.40239986777305603
# Epoch(1/3) : Batch no: (301/782) : Batch loss : 0.47659096121788025
# Epoch(1/3) : Batch no: (302/782) : Batch loss : 0.4221241772174835
# Epoch(1/3) : Batch no: (303/782) : Batch loss : 0.5236197710037231
# Epoch(1/3) : Batch no: (304/782) : Batch loss : 0.6922263503074646
# Epoch(1/3) : Batch no: (305/782) : Batch loss : 0.5887659788131714
# Epoch(1/3) : Batch no: (306/782) : Batch loss : 0.4983571767807007
# Epoch(1/3) : Batch no: (307/782) : Batch loss : 0.4268409311771393
# Epoch(1/3) : Batch no: (308/782) : Batch loss : 0.39201393723487854
# Epoch(1/3) : Batch no: (309/782) : Batch loss : 0.5329816341400146
# Epoch(1/3) : Batch no: (310/782) : Batch loss : 0.7064779996871948
# Epoch(1/3) : Batch no: (311/782) : Batch loss : 0.5892824530601501
# Epoch(1/3) : Batch no: (312/782) : Batch loss : 0.2760694921016693
# Epoch(1/3) : Batch no: (313/782) : Batch loss : 0.5415357947349548
# Epoch(1/3) : Batch no: (314/782) : Batch loss : 0.4225713908672333
# Epoch(1/3) : Batch no: (315/782) : Batch loss : 0.47131070494651794
# Epoch(1/3) : Batch no: (316/782) : Batch loss : 0.6149341464042664
# Epoch(1/3) : Batch no: (317/782) : Batch loss : 0.46656015515327454
# Epoch(1/3) : Batch no: (318/782) : Batch loss : 0.42947137355804443
# Epoch(1/3) : Batch no: (319/782) : Batch loss : 0.5330283045768738
# Epoch(1/3) : Batch no: (320/782) : Batch loss : 0.4008941650390625
# Epoch(1/3) : Batch no: (321/782) : Batch loss : 0.34174054861068726
# Epoch(1/3) : Batch no: (322/782) : Batch loss : 0.701064944267273
# Epoch(1/3) : Batch no: (323/782) : Batch loss : 0.7289225459098816
# Epoch(1/3) : Batch no: (324/782) : Batch loss : 0.4445946514606476
# Epoch(1/3) : Batch no: (325/782) : Batch loss : 0.28755033016204834
# Epoch(1/3) : Batch no: (326/782) : Batch loss : 0.5562787055969238
# Epoch(1/3) : Batch no: (327/782) : Batch loss : 0.526454508304596
# Epoch(1/3) : Batch no: (328/782) : Batch loss : 0.6095671057701111
# Epoch(1/3) : Batch no: (329/782) : Batch loss : 0.46583762764930725
# Epoch(1/3) : Batch no: (330/782) : Batch loss : 0.3998473584651947
# Epoch(1/3) : Batch no: (331/782) : Batch loss : 0.37637320160865784
# Epoch(1/3) : Batch no: (332/782) : Batch loss : 0.433712899684906
# Epoch(1/3) : Batch no: (333/782) : Batch loss : 0.5099000930786133
# Epoch(1/3) : Batch no: (334/782) : Batch loss : 0.6348810791969299
# Epoch(1/3) : Batch no: (335/782) : Batch loss : 0.3013521730899811
# Epoch(1/3) : Batch no: (336/782) : Batch loss : 0.5204739570617676
# Epoch(1/3) : Batch no: (337/782) : Batch loss : 0.43448883295059204
# Epoch(1/3) : Batch no: (338/782) : Batch loss : 0.5630198121070862
# Epoch(1/3) : Batch no: (339/782) : Batch loss : 0.4139038026332855
# Epoch(1/3) : Batch no: (340/782) : Batch loss : 0.6166235208511353
# Epoch(1/3) : Batch no: (341/782) : Batch loss : 0.3014732003211975
# Epoch(1/3) : Batch no: (342/782) : Batch loss : 0.41509249806404114
# Epoch(1/3) : Batch no: (343/782) : Batch loss : 0.29334375262260437
# Epoch(1/3) : Batch no: (344/782) : Batch loss : 0.5538978576660156
# Epoch(1/3) : Batch no: (345/782) : Batch loss : 0.4227159917354584
# Epoch(1/3) : Batch no: (346/782) : Batch loss : 0.3936815559864044
# Epoch(1/3) : Batch no: (347/782) : Batch loss : 0.3572095036506653
# Epoch(1/3) : Batch no: (348/782) : Batch loss : 0.28905412554740906
# Epoch(1/3) : Batch no: (349/782) : Batch loss : 0.5749629735946655
# Epoch(1/3) : Batch no: (350/782) : Batch loss : 0.405606746673584
# Epoch(1/3) : Batch no: (351/782) : Batch loss : 0.4582768678665161
# Epoch(1/3) : Batch no: (352/782) : Batch loss : 0.7127139568328857
# Epoch(1/3) : Batch no: (353/782) : Batch loss : 0.4543703496456146
# Epoch(1/3) : Batch no: (354/782) : Batch loss : 0.5329698324203491
# Epoch(1/3) : Batch no: (355/782) : Batch loss : 0.5556192398071289
# Epoch(1/3) : Batch no: (356/782) : Batch loss : 0.4734724462032318
# Epoch(1/3) : Batch no: (357/782) : Batch loss : 0.3564983308315277
# Epoch(1/3) : Batch no: (358/782) : Batch loss : 0.543557345867157
# Epoch(1/3) : Batch no: (359/782) : Batch loss : 0.3688018023967743
# Epoch(1/3) : Batch no: (360/782) : Batch loss : 0.46541494131088257
# Epoch(1/3) : Batch no: (361/782) : Batch loss : 0.528491199016571
# Epoch(1/3) : Batch no: (362/782) : Batch loss : 0.5942836999893188
# Epoch(1/3) : Batch no: (363/782) : Batch loss : 0.5235683917999268
# Epoch(1/3) : Batch no: (364/782) : Batch loss : 0.42005282640457153
# Epoch(1/3) : Batch no: (365/782) : Batch loss : 0.2903590798377991
# Epoch(1/3) : Batch no: (366/782) : Batch loss : 0.24744708836078644
# Epoch(1/3) : Batch no: (367/782) : Batch loss : 0.48898962140083313
# Epoch(1/3) : Batch no: (368/782) : Batch loss : 0.2660742402076721
# Epoch(1/3) : Batch no: (369/782) : Batch loss : 0.47547441720962524
# Epoch(1/3) : Batch no: (370/782) : Batch loss : 0.4669112265110016
# Epoch(1/3) : Batch no: (371/782) : Batch loss : 0.5369075536727905
# Epoch(1/3) : Batch no: (372/782) : Batch loss : 0.4150031805038452
# Epoch(1/3) : Batch no: (373/782) : Batch loss : 0.5013452768325806
# Epoch(1/3) : Batch no: (374/782) : Batch loss : 0.3160364329814911
# Epoch(1/3) : Batch no: (375/782) : Batch loss : 0.5914969444274902
# Epoch(1/3) : Batch no: (376/782) : Batch loss : 0.4950920045375824
# Epoch(1/3) : Batch no: (377/782) : Batch loss : 0.28270989656448364
# Epoch(1/3) : Batch no: (378/782) : Batch loss : 0.5831130743026733
# Epoch(1/3) : Batch no: (379/782) : Batch loss : 0.4454924166202545
# Epoch(1/3) : Batch no: (380/782) : Batch loss : 0.41185474395751953
# Epoch(1/3) : Batch no: (381/782) : Batch loss : 0.6054652333259583
# Epoch(1/3) : Batch no: (382/782) : Batch loss : 0.5650423765182495
# Epoch(1/3) : Batch no: (383/782) : Batch loss : 0.6508251428604126
# Epoch(1/3) : Batch no: (384/782) : Batch loss : 0.5067873597145081
# Epoch(1/3) : Batch no: (385/782) : Batch loss : 0.38482388854026794
# Epoch(1/3) : Batch no: (386/782) : Batch loss : 0.531035840511322
# Epoch(1/3) : Batch no: (387/782) : Batch loss : 0.6528089642524719
# Epoch(1/3) : Batch no: (388/782) : Batch loss : 0.3715932071208954
# Epoch(1/3) : Batch no: (389/782) : Batch loss : 0.3121247887611389
# Epoch(1/3) : Batch no: (390/782) : Batch loss : 0.3517187237739563
# Epoch(1/3) : Batch no: (391/782) : Batch loss : 0.5360928773880005
# Epoch(1/3) : Batch no: (392/782) : Batch loss : 0.3448031544685364
# Epoch(1/3) : Batch no: (393/782) : Batch loss : 0.3635774850845337
# Epoch(1/3) : Batch no: (394/782) : Batch loss : 0.5218421220779419
# Epoch(1/3) : Batch no: (395/782) : Batch loss : 0.6810771226882935
# Epoch(1/3) : Batch no: (396/782) : Batch loss : 0.4083341360092163
# Epoch(1/3) : Batch no: (397/782) : Batch loss : 0.6254395842552185
# Epoch(1/3) : Batch no: (398/782) : Batch loss : 0.6157025098800659
# Epoch(1/3) : Batch no: (399/782) : Batch loss : 0.5483306050300598
# Epoch(1/3) : Batch no: (400/782) : Batch loss : 0.6047387719154358
# Epoch(1/3) : Batch no: (401/782) : Batch loss : 0.5985004901885986
# Epoch(1/3) : Batch no: (402/782) : Batch loss : 0.3906182050704956
# Epoch(1/3) : Batch no: (403/782) : Batch loss : 0.37268123030662537
# Epoch(1/3) : Batch no: (404/782) : Batch loss : 0.46024519205093384
# Epoch(1/3) : Batch no: (405/782) : Batch loss : 0.6225423216819763
# Epoch(1/3) : Batch no: (406/782) : Batch loss : 0.5898429751396179
# Epoch(1/3) : Batch no: (407/782) : Batch loss : 0.4492715895175934
# Epoch(1/3) : Batch no: (408/782) : Batch loss : 0.33088019490242004
# Epoch(1/3) : Batch no: (409/782) : Batch loss : 0.429900199174881
# Epoch(1/3) : Batch no: (410/782) : Batch loss : 0.5517212152481079
# Epoch(1/3) : Batch no: (411/782) : Batch loss : 0.6035390496253967
# Epoch(1/3) : Batch no: (412/782) : Batch loss : 0.6196324229240417
# Epoch(1/3) : Batch no: (413/782) : Batch loss : 0.4652118384838104
# Epoch(1/3) : Batch no: (414/782) : Batch loss : 0.552035391330719
# Epoch(1/3) : Batch no: (415/782) : Batch loss : 0.4697626531124115
# Epoch(1/3) : Batch no: (416/782) : Batch loss : 0.6345729827880859
# Epoch(1/3) : Batch no: (417/782) : Batch loss : 0.5278679132461548
# Epoch(1/3) : Batch no: (418/782) : Batch loss : 0.3829047679901123
# Epoch(1/3) : Batch no: (419/782) : Batch loss : 0.28143173456192017
# Epoch(1/3) : Batch no: (420/782) : Batch loss : 0.4301093816757202
# Epoch(1/3) : Batch no: (421/782) : Batch loss : 0.271420955657959
# Epoch(1/3) : Batch no: (422/782) : Batch loss : 0.3779979348182678
# Epoch(1/3) : Batch no: (423/782) : Batch loss : 0.3897911012172699
# Epoch(1/3) : Batch no: (424/782) : Batch loss : 0.357845276594162
# Epoch(1/3) : Batch no: (425/782) : Batch loss : 0.38517582416534424
# Epoch(1/3) : Batch no: (426/782) : Batch loss : 0.44836297631263733
# Epoch(1/3) : Batch no: (427/782) : Batch loss : 0.4099380075931549
# Epoch(1/3) : Batch no: (428/782) : Batch loss : 0.4271455705165863
# Epoch(1/3) : Batch no: (429/782) : Batch loss : 0.48128262162208557
# Epoch(1/3) : Batch no: (430/782) : Batch loss : 0.33087965846061707
# Epoch(1/3) : Batch no: (431/782) : Batch loss : 0.24547713994979858
# Epoch(1/3) : Batch no: (432/782) : Batch loss : 0.6745507717132568
# Epoch(1/3) : Batch no: (433/782) : Batch loss : 0.46115750074386597
# Epoch(1/3) : Batch no: (434/782) : Batch loss : 0.574622392654419
# Epoch(1/3) : Batch no: (435/782) : Batch loss : 0.5247659087181091
# Epoch(1/3) : Batch no: (436/782) : Batch loss : 0.4906918406486511
# Epoch(1/3) : Batch no: (437/782) : Batch loss : 0.605831503868103
# Epoch(1/3) : Batch no: (438/782) : Batch loss : 0.550230085849762
# Epoch(1/3) : Batch no: (439/782) : Batch loss : 0.3410744071006775
# Epoch(1/3) : Batch no: (440/782) : Batch loss : 0.5782837271690369
# Epoch(1/3) : Batch no: (441/782) : Batch loss : 0.6579375267028809
# Epoch(1/3) : Batch no: (442/782) : Batch loss : 0.28460314869880676
# Epoch(1/3) : Batch no: (443/782) : Batch loss : 0.571131706237793
# Epoch(1/3) : Batch no: (444/782) : Batch loss : 0.5245686769485474
# Epoch(1/3) : Batch no: (445/782) : Batch loss : 0.3937487006187439
# Epoch(1/3) : Batch no: (446/782) : Batch loss : 0.4678446352481842
# Epoch(1/3) : Batch no: (447/782) : Batch loss : 0.37766891717910767
# Epoch(1/3) : Batch no: (448/782) : Batch loss : 0.4895557761192322
# Epoch(1/3) : Batch no: (449/782) : Batch loss : 0.5446413159370422
# Epoch(1/3) : Batch no: (450/782) : Batch loss : 0.5606869459152222
# Epoch(1/3) : Batch no: (451/782) : Batch loss : 0.4505918323993683
# Epoch(1/3) : Batch no: (452/782) : Batch loss : 0.22716176509857178
# Epoch(1/3) : Batch no: (453/782) : Batch loss : 0.4214094877243042
# Epoch(1/3) : Batch no: (454/782) : Batch loss : 0.6314944624900818
# Epoch(1/3) : Batch no: (455/782) : Batch loss : 0.45299288630485535
# Epoch(1/3) : Batch no: (456/782) : Batch loss : 0.3591787815093994
# Epoch(1/3) : Batch no: (457/782) : Batch loss : 0.5672805309295654
# Epoch(1/3) : Batch no: (458/782) : Batch loss : 0.442218542098999
# Epoch(1/3) : Batch no: (459/782) : Batch loss : 0.4648793637752533
# Epoch(1/3) : Batch no: (460/782) : Batch loss : 0.5930328369140625
# Epoch(1/3) : Batch no: (461/782) : Batch loss : 0.5154539346694946
# Epoch(1/3) : Batch no: (462/782) : Batch loss : 0.6558878421783447
# Epoch(1/3) : Batch no: (463/782) : Batch loss : 0.5261194705963135
# Epoch(1/3) : Batch no: (464/782) : Batch loss : 0.5343759655952454
# Epoch(1/3) : Batch no: (465/782) : Batch loss : 0.5075563788414001
# Epoch(1/3) : Batch no: (466/782) : Batch loss : 0.4103088974952698
# Epoch(1/3) : Batch no: (467/782) : Batch loss : 0.38724470138549805
# Epoch(1/3) : Batch no: (468/782) : Batch loss : 0.41786959767341614
# Epoch(1/3) : Batch no: (469/782) : Batch loss : 0.30048444867134094
# Epoch(1/3) : Batch no: (470/782) : Batch loss : 0.372199147939682
# Epoch(1/3) : Batch no: (471/782) : Batch loss : 0.6265737414360046
# Epoch(1/3) : Batch no: (472/782) : Batch loss : 0.5587925910949707
# Epoch(1/3) : Batch no: (473/782) : Batch loss : 0.3161660134792328
# Epoch(1/3) : Batch no: (474/782) : Batch loss : 0.5034425258636475
# Epoch(1/3) : Batch no: (475/782) : Batch loss : 0.3656451106071472
# Epoch(1/3) : Batch no: (476/782) : Batch loss : 0.19537405669689178
# Epoch(1/3) : Batch no: (477/782) : Batch loss : 0.5488279461860657
# Epoch(1/3) : Batch no: (478/782) : Batch loss : 0.3391779363155365
# Epoch(1/3) : Batch no: (479/782) : Batch loss : 0.45498791337013245
# Epoch(1/3) : Batch no: (480/782) : Batch loss : 0.33048632740974426
# Epoch(1/3) : Batch no: (481/782) : Batch loss : 0.4762362539768219
# Epoch(1/3) : Batch no: (482/782) : Batch loss : 0.5072206854820251
# Epoch(1/3) : Batch no: (483/782) : Batch loss : 0.5897722244262695
# Epoch(1/3) : Batch no: (484/782) : Batch loss : 0.4573064148426056
# Epoch(1/3) : Batch no: (485/782) : Batch loss : 0.5597609877586365
# Epoch(1/3) : Batch no: (486/782) : Batch loss : 0.43715333938598633
# Epoch(1/3) : Batch no: (487/782) : Batch loss : 0.3559046983718872
# Epoch(1/3) : Batch no: (488/782) : Batch loss : 0.3168340027332306
# Epoch(1/3) : Batch no: (489/782) : Batch loss : 0.3812224864959717
# Epoch(1/3) : Batch no: (490/782) : Batch loss : 0.45421168208122253
# Epoch(1/3) : Batch no: (491/782) : Batch loss : 0.41307783126831055
# Epoch(1/3) : Batch no: (492/782) : Batch loss : 0.5238348841667175
# Epoch(1/3) : Batch no: (493/782) : Batch loss : 0.33979082107543945
# Epoch(1/3) : Batch no: (494/782) : Batch loss : 0.33916351199150085
# Epoch(1/3) : Batch no: (495/782) : Batch loss : 0.5236786007881165
# Epoch(1/3) : Batch no: (496/782) : Batch loss : 0.46108299493789673
# Epoch(1/3) : Batch no: (497/782) : Batch loss : 0.3885476589202881
# Epoch(1/3) : Batch no: (498/782) : Batch loss : 0.7642805576324463
# Epoch(1/3) : Batch no: (499/782) : Batch loss : 0.3604201376438141
# Epoch(1/3) : Batch no: (500/782) : Batch loss : 0.33927321434020996
# Epoch(1/3) : Batch no: (501/782) : Batch loss : 0.4826855957508087
# Epoch(1/3) : Batch no: (502/782) : Batch loss : 0.5429852604866028
# Epoch(1/3) : Batch no: (503/782) : Batch loss : 0.4878880977630615
# Epoch(1/3) : Batch no: (504/782) : Batch loss : 0.4806070327758789
# Epoch(1/3) : Batch no: (505/782) : Batch loss : 0.5109393000602722
# Epoch(1/3) : Batch no: (506/782) : Batch loss : 0.8807413578033447
# Epoch(1/3) : Batch no: (507/782) : Batch loss : 0.5268082618713379
# Epoch(1/3) : Batch no: (508/782) : Batch loss : 0.3797028064727783
# Epoch(1/3) : Batch no: (509/782) : Batch loss : 0.22072462737560272
# Epoch(1/3) : Batch no: (510/782) : Batch loss : 0.5367599725723267
# Epoch(1/3) : Batch no: (511/782) : Batch loss : 0.5495879054069519
# Epoch(1/3) : Batch no: (512/782) : Batch loss : 0.4258093237876892
# Epoch(1/3) : Batch no: (513/782) : Batch loss : 0.48619458079338074
# Epoch(1/3) : Batch no: (514/782) : Batch loss : 0.46315476298332214
# Epoch(1/3) : Batch no: (515/782) : Batch loss : 0.5736863613128662
# Epoch(1/3) : Batch no: (516/782) : Batch loss : 0.48440343141555786
# Epoch(1/3) : Batch no: (517/782) : Batch loss : 0.4302164316177368
# Epoch(1/3) : Batch no: (518/782) : Batch loss : 0.36297205090522766
# Epoch(1/3) : Batch no: (519/782) : Batch loss : 0.40471696853637695
# Epoch(1/3) : Batch no: (520/782) : Batch loss : 0.6186387538909912
# Epoch(1/3) : Batch no: (521/782) : Batch loss : 0.6994016766548157
# Epoch(1/3) : Batch no: (522/782) : Batch loss : 0.42358502745628357
# Epoch(1/3) : Batch no: (523/782) : Batch loss : 0.3818429112434387
# Epoch(1/3) : Batch no: (524/782) : Batch loss : 0.46536898612976074
# Epoch(1/3) : Batch no: (525/782) : Batch loss : 0.37335580587387085
# Epoch(1/3) : Batch no: (526/782) : Batch loss : 0.5121413469314575
# Epoch(1/3) : Batch no: (527/782) : Batch loss : 0.5471418499946594
# Epoch(1/3) : Batch no: (528/782) : Batch loss : 0.38765212893486023
# Epoch(1/3) : Batch no: (529/782) : Batch loss : 0.3545554280281067
# Epoch(1/3) : Batch no: (530/782) : Batch loss : 0.45267969369888306
# Epoch(1/3) : Batch no: (531/782) : Batch loss : 0.4742339551448822
# Epoch(1/3) : Batch no: (532/782) : Batch loss : 0.4794241786003113
# Epoch(1/3) : Batch no: (533/782) : Batch loss : 0.6127234697341919
# Epoch(1/3) : Batch no: (534/782) : Batch loss : 0.650332510471344
# Epoch(1/3) : Batch no: (535/782) : Batch loss : 0.4131860136985779
# Epoch(1/3) : Batch no: (536/782) : Batch loss : 0.5536867380142212
# Epoch(1/3) : Batch no: (537/782) : Batch loss : 0.3720160126686096
# Epoch(1/3) : Batch no: (538/782) : Batch loss : 0.5297917723655701
# Epoch(1/3) : Batch no: (539/782) : Batch loss : 0.36855554580688477
# Epoch(1/3) : Batch no: (540/782) : Batch loss : 0.3448789119720459
# Epoch(1/3) : Batch no: (541/782) : Batch loss : 0.6008599400520325
# Epoch(1/3) : Batch no: (542/782) : Batch loss : 0.6590836048126221
# Epoch(1/3) : Batch no: (543/782) : Batch loss : 0.25593072175979614
# Epoch(1/3) : Batch no: (544/782) : Batch loss : 0.6044107675552368
# Epoch(1/3) : Batch no: (545/782) : Batch loss : 0.513415515422821
# Epoch(1/3) : Batch no: (546/782) : Batch loss : 0.3319888114929199
# Epoch(1/3) : Batch no: (547/782) : Batch loss : 0.4601283073425293
# Epoch(1/3) : Batch no: (548/782) : Batch loss : 0.5319653749465942
# Epoch(1/3) : Batch no: (549/782) : Batch loss : 0.3772276043891907
# Epoch(1/3) : Batch no: (550/782) : Batch loss : 0.559314489364624
# Epoch(1/3) : Batch no: (551/782) : Batch loss : 0.5803137421607971
# Epoch(1/3) : Batch no: (552/782) : Batch loss : 0.48204538226127625
# Epoch(1/3) : Batch no: (553/782) : Batch loss : 0.3155638575553894
# Epoch(1/3) : Batch no: (554/782) : Batch loss : 0.3972338140010834
# Epoch(1/3) : Batch no: (555/782) : Batch loss : 0.22337397933006287
# Epoch(1/3) : Batch no: (556/782) : Batch loss : 0.5054917931556702
# Epoch(1/3) : Batch no: (557/782) : Batch loss : 0.30196836590766907
# Epoch(1/3) : Batch no: (558/782) : Batch loss : 0.2390066385269165
# Epoch(1/3) : Batch no: (559/782) : Batch loss : 0.3004380762577057
# Epoch(1/3) : Batch no: (560/782) : Batch loss : 0.41022220253944397
# Epoch(1/3) : Batch no: (561/782) : Batch loss : 0.3403054475784302
# Epoch(1/3) : Batch no: (562/782) : Batch loss : 0.23411977291107178
# Epoch(1/3) : Batch no: (563/782) : Batch loss : 0.49324655532836914
# Epoch(1/3) : Batch no: (564/782) : Batch loss : 0.3001462519168854
# Epoch(1/3) : Batch no: (565/782) : Batch loss : 0.4191628396511078
# Epoch(1/3) : Batch no: (566/782) : Batch loss : 0.45543915033340454
# Epoch(1/3) : Batch no: (567/782) : Batch loss : 0.49353405833244324
# Epoch(1/3) : Batch no: (568/782) : Batch loss : 0.48452457785606384
# Epoch(1/3) : Batch no: (569/782) : Batch loss : 0.7275349497795105
# Epoch(1/3) : Batch no: (570/782) : Batch loss : 0.5492856502532959
# Epoch(1/3) : Batch no: (571/782) : Batch loss : 0.43788769841194153
# Epoch(1/3) : Batch no: (572/782) : Batch loss : 0.39794203639030457
# Epoch(1/3) : Batch no: (573/782) : Batch loss : 0.5069288015365601
# Epoch(1/3) : Batch no: (574/782) : Batch loss : 0.5375980734825134
# Epoch(1/3) : Batch no: (575/782) : Batch loss : 0.39294350147247314
# Epoch(1/3) : Batch no: (576/782) : Batch loss : 0.2712102234363556
# Epoch(1/3) : Batch no: (577/782) : Batch loss : 0.3920874297618866
# Epoch(1/3) : Batch no: (578/782) : Batch loss : 0.5792778134346008
# Epoch(1/3) : Batch no: (579/782) : Batch loss : 0.37500861287117004
# Epoch(1/3) : Batch no: (580/782) : Batch loss : 0.42096543312072754
# Epoch(1/3) : Batch no: (581/782) : Batch loss : 0.41330069303512573
# Epoch(1/3) : Batch no: (582/782) : Batch loss : 0.39341792464256287
# Epoch(1/3) : Batch no: (583/782) : Batch loss : 0.49398961663246155
# Epoch(1/3) : Batch no: (584/782) : Batch loss : 0.6614524126052856
# Epoch(1/3) : Batch no: (585/782) : Batch loss : 0.5106766819953918
# Epoch(1/3) : Batch no: (586/782) : Batch loss : 0.3704235851764679
# Epoch(1/3) : Batch no: (587/782) : Batch loss : 0.30515676736831665
# Epoch(1/3) : Batch no: (588/782) : Batch loss : 0.474124550819397
# Epoch(1/3) : Batch no: (589/782) : Batch loss : 0.3438486158847809
# Epoch(1/3) : Batch no: (590/782) : Batch loss : 0.3339952230453491
# Epoch(1/3) : Batch no: (591/782) : Batch loss : 0.5830550789833069
# Epoch(1/3) : Batch no: (592/782) : Batch loss : 0.29667210578918457
# Epoch(1/3) : Batch no: (593/782) : Batch loss : 0.39868858456611633
# Epoch(1/3) : Batch no: (594/782) : Batch loss : 0.36468470096588135
# Epoch(1/3) : Batch no: (595/782) : Batch loss : 0.38570645451545715
# Epoch(1/3) : Batch no: (596/782) : Batch loss : 0.5395455956459045
# Epoch(1/3) : Batch no: (597/782) : Batch loss : 0.6054486632347107
# Epoch(1/3) : Batch no: (598/782) : Batch loss : 0.7254047989845276
# Epoch(1/3) : Batch no: (599/782) : Batch loss : 0.3868665099143982
# Epoch(1/3) : Batch no: (600/782) : Batch loss : 0.43173637986183167
# Epoch(1/3) : Batch no: (601/782) : Batch loss : 0.354851096868515
# Epoch(1/3) : Batch no: (602/782) : Batch loss : 0.5316330194473267
# Epoch(1/3) : Batch no: (603/782) : Batch loss : 0.5784051418304443
# Epoch(1/3) : Batch no: (604/782) : Batch loss : 0.4826842248439789
# Epoch(1/3) : Batch no: (605/782) : Batch loss : 0.44271793961524963
# Epoch(1/3) : Batch no: (606/782) : Batch loss : 0.48441794514656067
# Epoch(1/3) : Batch no: (607/782) : Batch loss : 0.2712509334087372
# Epoch(1/3) : Batch no: (608/782) : Batch loss : 0.513914167881012
# Epoch(1/3) : Batch no: (609/782) : Batch loss : 0.3122212886810303
# Epoch(1/3) : Batch no: (610/782) : Batch loss : 0.42501533031463623
# Epoch(1/3) : Batch no: (611/782) : Batch loss : 0.282899409532547
# Epoch(1/3) : Batch no: (612/782) : Batch loss : 0.25191256403923035
# Epoch(1/3) : Batch no: (613/782) : Batch loss : 0.3003973960876465
# Epoch(1/3) : Batch no: (614/782) : Batch loss : 0.682406485080719
# Epoch(1/3) : Batch no: (615/782) : Batch loss : 0.3337448239326477
# Epoch(1/3) : Batch no: (616/782) : Batch loss : 0.34939736127853394
# Epoch(1/3) : Batch no: (617/782) : Batch loss : 0.4144866466522217
# Epoch(1/3) : Batch no: (618/782) : Batch loss : 0.35650208592414856
# Epoch(1/3) : Batch no: (619/782) : Batch loss : 0.5802240967750549
# Epoch(1/3) : Batch no: (620/782) : Batch loss : 0.6482035517692566
# Epoch(1/3) : Batch no: (621/782) : Batch loss : 0.5848376750946045
# Epoch(1/3) : Batch no: (622/782) : Batch loss : 0.34684810042381287
# Epoch(1/3) : Batch no: (623/782) : Batch loss : 0.5297464728355408
# Epoch(1/3) : Batch no: (624/782) : Batch loss : 0.29077062010765076
# Epoch(1/3) : Batch no: (625/782) : Batch loss : 0.534077525138855
# Epoch(1/3) : Batch no: (626/782) : Batch loss : 0.30115988850593567
# Epoch(1/3) : Batch no: (627/782) : Batch loss : 0.49197646975517273
# Epoch(1/3) : Batch no: (628/782) : Batch loss : 0.5005375742912292
# Epoch(1/3) : Batch no: (629/782) : Batch loss : 0.38901248574256897
# Epoch(1/3) : Batch no: (630/782) : Batch loss : 0.3959292471408844
# Epoch(1/3) : Batch no: (631/782) : Batch loss : 0.33295750617980957
# Epoch(1/3) : Batch no: (632/782) : Batch loss : 0.47254830598831177
# Epoch(1/3) : Batch no: (633/782) : Batch loss : 0.4350666105747223
# Epoch(1/3) : Batch no: (634/782) : Batch loss : 0.2856379449367523
# Epoch(1/3) : Batch no: (635/782) : Batch loss : 0.3698735535144806
# Epoch(1/3) : Batch no: (636/782) : Batch loss : 0.46012598276138306
# Epoch(1/3) : Batch no: (637/782) : Batch loss : 0.38813069462776184
# Epoch(1/3) : Batch no: (638/782) : Batch loss : 0.319024920463562
# Epoch(1/3) : Batch no: (639/782) : Batch loss : 0.71934574842453
# Epoch(1/3) : Batch no: (640/782) : Batch loss : 0.41289371252059937
# Epoch(1/3) : Batch no: (641/782) : Batch loss : 0.3688652813434601
# Epoch(1/3) : Batch no: (642/782) : Batch loss : 0.5319095253944397
# Epoch(1/3) : Batch no: (643/782) : Batch loss : 0.45541438460350037
# Epoch(1/3) : Batch no: (644/782) : Batch loss : 0.3610241413116455
# Epoch(1/3) : Batch no: (645/782) : Batch loss : 0.3298724889755249
# Epoch(1/3) : Batch no: (646/782) : Batch loss : 0.4083339273929596
# Epoch(1/3) : Batch no: (647/782) : Batch loss : 0.29598891735076904
# Epoch(1/3) : Batch no: (648/782) : Batch loss : 0.5677122473716736
# Epoch(1/3) : Batch no: (649/782) : Batch loss : 0.42263826727867126
# Epoch(1/3) : Batch no: (650/782) : Batch loss : 0.36806848645210266
# Epoch(1/3) : Batch no: (651/782) : Batch loss : 0.4215611219406128
# Epoch(1/3) : Batch no: (652/782) : Batch loss : 0.5056650638580322
# Epoch(1/3) : Batch no: (653/782) : Batch loss : 0.3779959976673126
# Epoch(1/3) : Batch no: (654/782) : Batch loss : 0.2908046543598175
# Epoch(1/3) : Batch no: (655/782) : Batch loss : 0.4870697557926178
# Epoch(1/3) : Batch no: (656/782) : Batch loss : 0.527626633644104
# Epoch(1/3) : Batch no: (657/782) : Batch loss : 0.5347057580947876
# Epoch(1/3) : Batch no: (658/782) : Batch loss : 0.3258856236934662
# Epoch(1/3) : Batch no: (659/782) : Batch loss : 0.4247681796550751
# Epoch(1/3) : Batch no: (660/782) : Batch loss : 0.49190807342529297
# Epoch(1/3) : Batch no: (661/782) : Batch loss : 0.5435899496078491
# Epoch(1/3) : Batch no: (662/782) : Batch loss : 0.5950385928153992
# Epoch(1/3) : Batch no: (663/782) : Batch loss : 0.46921345591545105
# Epoch(1/3) : Batch no: (664/782) : Batch loss : 0.3915182650089264
# Epoch(1/3) : Batch no: (665/782) : Batch loss : 0.6113253831863403
# Epoch(1/3) : Batch no: (666/782) : Batch loss : 0.6474514603614807
# Epoch(1/3) : Batch no: (667/782) : Batch loss : 0.3792737126350403
# Epoch(1/3) : Batch no: (668/782) : Batch loss : 0.4894680976867676
# Epoch(1/3) : Batch no: (669/782) : Batch loss : 0.666000247001648
# Epoch(1/3) : Batch no: (670/782) : Batch loss : 0.698278546333313
# Epoch(1/3) : Batch no: (671/782) : Batch loss : 0.43523234128952026
# Epoch(1/3) : Batch no: (672/782) : Batch loss : 0.4139690399169922
# Epoch(1/3) : Batch no: (673/782) : Batch loss : 0.36419379711151123
# Epoch(1/3) : Batch no: (674/782) : Batch loss : 0.32839104533195496
# Epoch(1/3) : Batch no: (675/782) : Batch loss : 0.5619845986366272
# Epoch(1/3) : Batch no: (676/782) : Batch loss : 0.33827367424964905
# Epoch(1/3) : Batch no: (677/782) : Batch loss : 0.2447991967201233
# Epoch(1/3) : Batch no: (678/782) : Batch loss : 0.3287823498249054
# Epoch(1/3) : Batch no: (679/782) : Batch loss : 0.32392218708992004
# Epoch(1/3) : Batch no: (680/782) : Batch loss : 0.3888646960258484
# Epoch(1/3) : Batch no: (681/782) : Batch loss : 0.3671034574508667
# Epoch(1/3) : Batch no: (682/782) : Batch loss : 0.3183559477329254
# Epoch(1/3) : Batch no: (683/782) : Batch loss : 0.4587709605693817
# Epoch(1/3) : Batch no: (684/782) : Batch loss : 0.3750881254673004
# Epoch(1/3) : Batch no: (685/782) : Batch loss : 0.3263886868953705
# Epoch(1/3) : Batch no: (686/782) : Batch loss : 0.49738243222236633
# Epoch(1/3) : Batch no: (687/782) : Batch loss : 0.34234511852264404
# Epoch(1/3) : Batch no: (688/782) : Batch loss : 0.3936978876590729
# Epoch(1/3) : Batch no: (689/782) : Batch loss : 0.34175413846969604
# Epoch(1/3) : Batch no: (690/782) : Batch loss : 0.5297060012817383
# Epoch(1/3) : Batch no: (691/782) : Batch loss : 0.5422922372817993
# Epoch(1/3) : Batch no: (692/782) : Batch loss : 0.38679391145706177
# Epoch(1/3) : Batch no: (693/782) : Batch loss : 0.6305772662162781
# Epoch(1/3) : Batch no: (694/782) : Batch loss : 0.4108187258243561
# Epoch(1/3) : Batch no: (695/782) : Batch loss : 0.46623659133911133
# Epoch(1/3) : Batch no: (696/782) : Batch loss : 0.21007853746414185
# Epoch(1/3) : Batch no: (697/782) : Batch loss : 0.588038980960846
# Epoch(1/3) : Batch no: (698/782) : Batch loss : 0.5581895112991333
# Epoch(1/3) : Batch no: (699/782) : Batch loss : 0.5497494339942932
# Epoch(1/3) : Batch no: (700/782) : Batch loss : 0.4009045362472534
# Epoch(1/3) : Batch no: (701/782) : Batch loss : 0.3380421996116638
# Epoch(1/3) : Batch no: (702/782) : Batch loss : 0.36698296666145325
# Epoch(1/3) : Batch no: (703/782) : Batch loss : 0.506092369556427
# Epoch(1/3) : Batch no: (704/782) : Batch loss : 0.45542511343955994
# Epoch(1/3) : Batch no: (705/782) : Batch loss : 0.41925156116485596
# Epoch(1/3) : Batch no: (706/782) : Batch loss : 0.4336078464984894
# Epoch(1/3) : Batch no: (707/782) : Batch loss : 0.5722336769104004
# Epoch(1/3) : Batch no: (708/782) : Batch loss : 0.34764522314071655
# Epoch(1/3) : Batch no: (709/782) : Batch loss : 0.24515841901302338
# Epoch(1/3) : Batch no: (710/782) : Batch loss : 0.5938566327095032
# Epoch(1/3) : Batch no: (711/782) : Batch loss : 0.38010460138320923
# Epoch(1/3) : Batch no: (712/782) : Batch loss : 0.48014959692955017
# Epoch(1/3) : Batch no: (713/782) : Batch loss : 0.44272202253341675
# Epoch(1/3) : Batch no: (714/782) : Batch loss : 0.3612000644207001
# Epoch(1/3) : Batch no: (715/782) : Batch loss : 0.45221948623657227
# Epoch(1/3) : Batch no: (716/782) : Batch loss : 0.4342081844806671
# Epoch(1/3) : Batch no: (717/782) : Batch loss : 0.5251796841621399
# Epoch(1/3) : Batch no: (718/782) : Batch loss : 0.5195486545562744
# Epoch(1/3) : Batch no: (719/782) : Batch loss : 0.3179704248905182
# Epoch(1/3) : Batch no: (720/782) : Batch loss : 0.3388049304485321
# Epoch(1/3) : Batch no: (721/782) : Batch loss : 0.5172998309135437
# Epoch(1/3) : Batch no: (722/782) : Batch loss : 0.47229933738708496
# Epoch(1/3) : Batch no: (723/782) : Batch loss : 0.3704564869403839
# Epoch(1/3) : Batch no: (724/782) : Batch loss : 0.3225693702697754
# Epoch(1/3) : Batch no: (725/782) : Batch loss : 0.2716841995716095
# Epoch(1/3) : Batch no: (726/782) : Batch loss : 0.7238984704017639
# Epoch(1/3) : Batch no: (727/782) : Batch loss : 0.6582345962524414
# Epoch(1/3) : Batch no: (728/782) : Batch loss : 0.4546939730644226
# Epoch(1/3) : Batch no: (729/782) : Batch loss : 0.43146175146102905
# Epoch(1/3) : Batch no: (730/782) : Batch loss : 0.4551818072795868
# Epoch(1/3) : Batch no: (731/782) : Batch loss : 0.556105375289917
# Epoch(1/3) : Batch no: (732/782) : Batch loss : 0.5587494969367981
# Epoch(1/3) : Batch no: (733/782) : Batch loss : 0.5148912072181702
# Epoch(1/3) : Batch no: (734/782) : Batch loss : 0.5697404146194458
# Epoch(1/3) : Batch no: (735/782) : Batch loss : 0.43266019225120544
# Epoch(1/3) : Batch no: (736/782) : Batch loss : 0.3904414772987366
# Epoch(1/3) : Batch no: (737/782) : Batch loss : 0.39219099283218384
# Epoch(1/3) : Batch no: (738/782) : Batch loss : 0.42110130190849304
# Epoch(1/3) : Batch no: (739/782) : Batch loss : 0.565318763256073
# Epoch(1/3) : Batch no: (740/782) : Batch loss : 0.37742552161216736
# Epoch(1/3) : Batch no: (741/782) : Batch loss : 0.5798213481903076
# Epoch(1/3) : Batch no: (742/782) : Batch loss : 0.6496856212615967
# Epoch(1/3) : Batch no: (743/782) : Batch loss : 0.4003720283508301
# Epoch(1/3) : Batch no: (744/782) : Batch loss : 0.33434128761291504
# Epoch(1/3) : Batch no: (745/782) : Batch loss : 0.4328027367591858
# Epoch(1/3) : Batch no: (746/782) : Batch loss : 0.41319969296455383
# Epoch(1/3) : Batch no: (747/782) : Batch loss : 0.5275385975837708
# Epoch(1/3) : Batch no: (748/782) : Batch loss : 0.47497814893722534
# Epoch(1/3) : Batch no: (749/782) : Batch loss : 0.3246992826461792
# Epoch(1/3) : Batch no: (750/782) : Batch loss : 0.5029321312904358
# Epoch(1/3) : Batch no: (751/782) : Batch loss : 0.40973594784736633
# Epoch(1/3) : Batch no: (752/782) : Batch loss : 0.590368390083313
# Epoch(1/3) : Batch no: (753/782) : Batch loss : 0.5327323079109192
# Epoch(1/3) : Batch no: (754/782) : Batch loss : 0.32706835865974426
# Epoch(1/3) : Batch no: (755/782) : Batch loss : 0.36766213178634644
# Epoch(1/3) : Batch no: (756/782) : Batch loss : 0.40719276666641235
# Epoch(1/3) : Batch no: (757/782) : Batch loss : 0.33889636397361755
# Epoch(1/3) : Batch no: (758/782) : Batch loss : 0.29146531224250793
# Epoch(1/3) : Batch no: (759/782) : Batch loss : 0.458717405796051
# Epoch(1/3) : Batch no: (760/782) : Batch loss : 0.5722304582595825
# Epoch(1/3) : Batch no: (761/782) : Batch loss : 0.42632415890693665
# Epoch(1/3) : Batch no: (762/782) : Batch loss : 0.44413647055625916
# Epoch(1/3) : Batch no: (763/782) : Batch loss : 0.4581373333930969
# Epoch(1/3) : Batch no: (764/782) : Batch loss : 0.6556186676025391
# Epoch(1/3) : Batch no: (765/782) : Batch loss : 0.5669006705284119
# Epoch(1/3) : Batch no: (766/782) : Batch loss : 0.19667395949363708
# Epoch(1/3) : Batch no: (767/782) : Batch loss : 0.6600468158721924
# Epoch(1/3) : Batch no: (768/782) : Batch loss : 0.2629624307155609
# Epoch(1/3) : Batch no: (769/782) : Batch loss : 0.5098124742507935
# Epoch(1/3) : Batch no: (770/782) : Batch loss : 0.4737561047077179
# Epoch(1/3) : Batch no: (771/782) : Batch loss : 0.44401100277900696
# Epoch(1/3) : Batch no: (772/782) : Batch loss : 0.29187679290771484
# Epoch(1/3) : Batch no: (773/782) : Batch loss : 0.326728880405426
# Epoch(1/3) : Batch no: (774/782) : Batch loss : 0.3797297775745392
# Epoch(1/3) : Batch no: (775/782) : Batch loss : 0.38966622948646545
# Epoch(1/3) : Batch no: (776/782) : Batch loss : 0.34593892097473145
# Epoch(1/3) : Batch no: (777/782) : Batch loss : 0.5878704190254211
# Epoch(1/3) : Batch no: (778/782) : Batch loss : 0.38768160343170166
# Epoch(1/3) : Batch no: (779/782) : Batch loss : 0.4543449878692627
# Epoch(1/3) : Batch no: (780/782) : Batch loss : 0.6363840699195862
# Epoch(1/3) : Batch no: (781/782) : Batch loss : 0.5245136022567749
# Epoch(1/3) : Batch no: (782/782) : Batch loss : 0.25028350949287415
# Training loss : 0.4646681527538068
# Epoch(2/3) : Batch no: (1/782) : Batch loss : 0.47487255930900574
# Epoch(2/3) : Batch no: (2/782) : Batch loss : 0.3620215654373169
# Epoch(2/3) : Batch no: (3/782) : Batch loss : 0.49066290259361267
# Epoch(2/3) : Batch no: (4/782) : Batch loss : 0.33812496066093445
# Epoch(2/3) : Batch no: (5/782) : Batch loss : 0.33631283044815063
# Epoch(2/3) : Batch no: (6/782) : Batch loss : 0.2688416838645935
# Epoch(2/3) : Batch no: (7/782) : Batch loss : 0.5181230306625366
# Epoch(2/3) : Batch no: (8/782) : Batch loss : 0.29004889726638794
# Epoch(2/3) : Batch no: (9/782) : Batch loss : 0.2645881175994873
# Epoch(2/3) : Batch no: (10/782) : Batch loss : 0.40730035305023193
# Epoch(2/3) : Batch no: (11/782) : Batch loss : 0.28362172842025757
# Epoch(2/3) : Batch no: (12/782) : Batch loss : 0.3305217921733856
# Epoch(2/3) : Batch no: (13/782) : Batch loss : 0.2533532977104187
# Epoch(2/3) : Batch no: (14/782) : Batch loss : 0.333524227142334
# Epoch(2/3) : Batch no: (15/782) : Batch loss : 0.3917318284511566
# Epoch(2/3) : Batch no: (16/782) : Batch loss : 0.3957050144672394
# Epoch(2/3) : Batch no: (17/782) : Batch loss : 0.4655763506889343
# Epoch(2/3) : Batch no: (18/782) : Batch loss : 0.775531530380249
# Epoch(2/3) : Batch no: (19/782) : Batch loss : 0.19125273823738098
# Epoch(2/3) : Batch no: (20/782) : Batch loss : 0.28614541888237
# Epoch(2/3) : Batch no: (21/782) : Batch loss : 0.258858859539032
# Epoch(2/3) : Batch no: (22/782) : Batch loss : 0.37844547629356384
# Epoch(2/3) : Batch no: (23/782) : Batch loss : 0.44993847608566284
# Epoch(2/3) : Batch no: (24/782) : Batch loss : 0.3646780848503113
# Epoch(2/3) : Batch no: (25/782) : Batch loss : 0.5116758942604065
# Epoch(2/3) : Batch no: (26/782) : Batch loss : 0.33025529980659485
# Epoch(2/3) : Batch no: (27/782) : Batch loss : 0.24817630648612976
# Epoch(2/3) : Batch no: (28/782) : Batch loss : 0.2212064564228058
# Epoch(2/3) : Batch no: (29/782) : Batch loss : 0.3996284604072571
# Epoch(2/3) : Batch no: (30/782) : Batch loss : 0.3136587142944336
# Epoch(2/3) : Batch no: (31/782) : Batch loss : 0.3066471815109253
# Epoch(2/3) : Batch no: (32/782) : Batch loss : 0.3558233380317688
# Epoch(2/3) : Batch no: (33/782) : Batch loss : 0.4725441634654999
# Epoch(2/3) : Batch no: (34/782) : Batch loss : 0.435470849275589
# Epoch(2/3) : Batch no: (35/782) : Batch loss : 0.40861275792121887
# Epoch(2/3) : Batch no: (36/782) : Batch loss : 0.21583430469036102
# Epoch(2/3) : Batch no: (37/782) : Batch loss : 0.3503849506378174
# Epoch(2/3) : Batch no: (38/782) : Batch loss : 0.21976789832115173
# Epoch(2/3) : Batch no: (39/782) : Batch loss : 0.4091326892375946
# Epoch(2/3) : Batch no: (40/782) : Batch loss : 0.3197712004184723
# Epoch(2/3) : Batch no: (41/782) : Batch loss : 0.3399992287158966
# Epoch(2/3) : Batch no: (42/782) : Batch loss : 0.37236568331718445
# Epoch(2/3) : Batch no: (43/782) : Batch loss : 0.38599616289138794
# Epoch(2/3) : Batch no: (44/782) : Batch loss : 0.2781539857387543
# Epoch(2/3) : Batch no: (45/782) : Batch loss : 0.32659491896629333
# Epoch(2/3) : Batch no: (46/782) : Batch loss : 0.4064439535140991
# Epoch(2/3) : Batch no: (47/782) : Batch loss : 0.17497363686561584
# Epoch(2/3) : Batch no: (48/782) : Batch loss : 0.3374772071838379
# Epoch(2/3) : Batch no: (49/782) : Batch loss : 0.37404197454452515
# Epoch(2/3) : Batch no: (50/782) : Batch loss : 0.2534477412700653
# Epoch(2/3) : Batch no: (51/782) : Batch loss : 0.4543456733226776
# Epoch(2/3) : Batch no: (52/782) : Batch loss : 0.2247387170791626
# Epoch(2/3) : Batch no: (53/782) : Batch loss : 0.3720146715641022
# Epoch(2/3) : Batch no: (54/782) : Batch loss : 0.4550023674964905
# Epoch(2/3) : Batch no: (55/782) : Batch loss : 0.4046960175037384
# Epoch(2/3) : Batch no: (56/782) : Batch loss : 0.5019534230232239
# Epoch(2/3) : Batch no: (57/782) : Batch loss : 0.2523679733276367
# Epoch(2/3) : Batch no: (58/782) : Batch loss : 0.39601191878318787
# Epoch(2/3) : Batch no: (59/782) : Batch loss : 0.34995704889297485
# Epoch(2/3) : Batch no: (60/782) : Batch loss : 0.24200788140296936
# Epoch(2/3) : Batch no: (61/782) : Batch loss : 0.17039461433887482
# Epoch(2/3) : Batch no: (62/782) : Batch loss : 0.17160215973854065
# Epoch(2/3) : Batch no: (63/782) : Batch loss : 0.3995133638381958
# Epoch(2/3) : Batch no: (64/782) : Batch loss : 0.37786784768104553
# Epoch(2/3) : Batch no: (65/782) : Batch loss : 0.6363334059715271
# Epoch(2/3) : Batch no: (66/782) : Batch loss : 0.40539029240608215
# Epoch(2/3) : Batch no: (67/782) : Batch loss : 0.3346753418445587
# Epoch(2/3) : Batch no: (68/782) : Batch loss : 0.27894046902656555
# Epoch(2/3) : Batch no: (69/782) : Batch loss : 0.30725401639938354
# Epoch(2/3) : Batch no: (70/782) : Batch loss : 0.5020931363105774
# Epoch(2/3) : Batch no: (71/782) : Batch loss : 0.21040195226669312
# Epoch(2/3) : Batch no: (72/782) : Batch loss : 0.4405473470687866
# Epoch(2/3) : Batch no: (73/782) : Batch loss : 0.32379379868507385
# Epoch(2/3) : Batch no: (74/782) : Batch loss : 0.4197514057159424
# Epoch(2/3) : Batch no: (75/782) : Batch loss : 0.40087634325027466
# Epoch(2/3) : Batch no: (76/782) : Batch loss : 0.1529327630996704
# Epoch(2/3) : Batch no: (77/782) : Batch loss : 0.31912893056869507
# Epoch(2/3) : Batch no: (78/782) : Batch loss : 0.36420828104019165
# Epoch(2/3) : Batch no: (79/782) : Batch loss : 0.507461428642273
# Epoch(2/3) : Batch no: (80/782) : Batch loss : 0.388815313577652
# Epoch(2/3) : Batch no: (81/782) : Batch loss : 0.40006905794143677
# Epoch(2/3) : Batch no: (82/782) : Batch loss : 0.290697306394577
# Epoch(2/3) : Batch no: (83/782) : Batch loss : 0.26214903593063354
# Epoch(2/3) : Batch no: (84/782) : Batch loss : 0.4681735634803772
# Epoch(2/3) : Batch no: (85/782) : Batch loss : 0.3944892883300781
# Epoch(2/3) : Batch no: (86/782) : Batch loss : 0.36876988410949707
# Epoch(2/3) : Batch no: (87/782) : Batch loss : 0.3828330338001251
# Epoch(2/3) : Batch no: (88/782) : Batch loss : 0.2749420404434204
# Epoch(2/3) : Batch no: (89/782) : Batch loss : 0.3164781928062439
# Epoch(2/3) : Batch no: (90/782) : Batch loss : 0.3859815001487732
# Epoch(2/3) : Batch no: (91/782) : Batch loss : 0.3934934139251709
# Epoch(2/3) : Batch no: (92/782) : Batch loss : 0.2910451591014862
# Epoch(2/3) : Batch no: (93/782) : Batch loss : 0.28966712951660156
# Epoch(2/3) : Batch no: (94/782) : Batch loss : 0.3647312819957733
# Epoch(2/3) : Batch no: (95/782) : Batch loss : 0.33755213022232056
# Epoch(2/3) : Batch no: (96/782) : Batch loss : 0.3591313660144806
# Epoch(2/3) : Batch no: (97/782) : Batch loss : 0.45391911268234253
# Epoch(2/3) : Batch no: (98/782) : Batch loss : 0.1651054322719574
# Epoch(2/3) : Batch no: (99/782) : Batch loss : 0.36829638481140137
# Epoch(2/3) : Batch no: (100/782) : Batch loss : 0.3362949788570404
# Epoch(2/3) : Batch no: (101/782) : Batch loss : 0.29778075218200684
# Epoch(2/3) : Batch no: (102/782) : Batch loss : 0.22529803216457367
# Epoch(2/3) : Batch no: (103/782) : Batch loss : 0.2770969569683075
# Epoch(2/3) : Batch no: (104/782) : Batch loss : 0.38974639773368835
# Epoch(2/3) : Batch no: (105/782) : Batch loss : 0.2332630455493927
# Epoch(2/3) : Batch no: (106/782) : Batch loss : 0.3606286644935608
# Epoch(2/3) : Batch no: (107/782) : Batch loss : 0.23290570080280304
# Epoch(2/3) : Batch no: (108/782) : Batch loss : 0.3590359389781952
# Epoch(2/3) : Batch no: (109/782) : Batch loss : 0.41729211807250977
# Epoch(2/3) : Batch no: (110/782) : Batch loss : 0.44379788637161255
# Epoch(2/3) : Batch no: (111/782) : Batch loss : 0.2248040735721588
# Epoch(2/3) : Batch no: (112/782) : Batch loss : 0.3552960753440857
# Epoch(2/3) : Batch no: (113/782) : Batch loss : 0.1343706250190735
# Epoch(2/3) : Batch no: (114/782) : Batch loss : 0.2975628077983856
# Epoch(2/3) : Batch no: (115/782) : Batch loss : 0.3209858536720276
# Epoch(2/3) : Batch no: (116/782) : Batch loss : 0.18598788976669312
# Epoch(2/3) : Batch no: (117/782) : Batch loss : 0.4277637004852295
# Epoch(2/3) : Batch no: (118/782) : Batch loss : 0.39894920587539673
# Epoch(2/3) : Batch no: (119/782) : Batch loss : 0.2847493588924408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f9bd44eefebf> in <cell line: 5>()
#      16     optimizer.step()
#      17
# ---> 18     batch_loss += loss.item()
#      19     print(f'Epoch({i+1}/{epochs}) : Batch no: ({batch_n}/{len(train_loader)}) : Batch loss : {loss.item()}')
#      20
#
# KeyboardInterrupt:

# %% [markdown]
# ### Get Accuracy

# %%
model.to('cpu')

model.eval()
with torch.no_grad():
    num_correct = 0
    total = 0

    for batch_n, (X_test, y_test) in enumerate(test_loader,1):

        y_pred = model(X_test)
        sfmax = torch.exp(y_pred)  # take exp as output is log of softmax

        y_pred_class = torch.argmax(sfmax, 1)
        total += labels.size(0)
        num_correct += (y_pred_class == y_test).sum().item()
        print(f'Batch ({batch_n}/{len(test_loader)})')

        if batch_n == 5:
          break

    print(f'Accuracy of the model on {total} test images: {num_correct * 100 / total}% ')
# Out:
# Batch (1/157)
# Batch (2/157)
# Batch (3/157)
# Batch (4/157)
# Batch (5/157)
# Accuracy of the model on 320 test images: 84.6875%
